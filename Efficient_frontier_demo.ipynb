# %% [markdown]
# <a href="https://colab.research.google.com/github/JacquesYL/MEF/blob/main/Efficient_frontier_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import key librares and modules
import pandas as pd
import numpy as np

# Import datetime module that comes pre-installed in Python
# datetime offers classes that work with date & time information
import datetime as dta

import matplotlib.pyplot as plt

# !pip install seaborn
import seaborn as sns

import plotly.express as px

# %%
# Define a function that performs interactive data visualization using Plotly Express
def plot_financial_data(df, title):

    fig = px.line(title = title)

    # For loop that plots all stock prices in the pandas dataframe df
    # Note that index starts with 1 because we want to skip the date column

    #skip the date, so the column starts with index = 1 (date is when index = 0)
    for i in df.columns[1:]:
        fig.add_scatter(x = df['Date'], y = df[i], name = i)
        fig.update_traces(line_width = 1)
        fig.update_layout({'plot_bgcolor': "white"})

    fig.show()

# %%
# Function to scale stock prices based on their initial starting price
# The objective of this function is to set all prices to start at a value of 1
def price_scaling(raw_prices_df):
    scaled_prices_df = raw_prices_df.copy()
    for i in raw_prices_df.columns[1:]:
          scaled_prices_df[i] = raw_prices_df[i]/raw_prices_df[i][0]
    return scaled_prices_df

# %%
import random

def generate_portfolio_weights(n):
    weights = []
    for i in range(n):
        weights.append(random.random())

    # let's make the sum of all weights add up to 1
    weights = weights/np.sum(weights)
    return weights

# %%
# Assume that we have $1,000,000 that we would like to invest in one or more of the selected stocks
# Let's create a function that receives the following arguments:
      # (1) Stocks closing prices
      # (2) Random weights
      # (3) Initial investment amount
# The function will return a DataFrame that contains the following:
      # (1) Daily value (position) of each individual stock over the specified time period
      # (2) Total daily value of the portfolio
      # (3) Percentage daily return

def asset_allocation(df, weights, initial_investment):
    portfolio_df = df.copy()

    # Scale stock prices using the "price_scaling" function that we defined earlier (Make them all start at 1)
    scaled_df = price_scaling(df)

    for i, stock in enumerate(scaled_df.columns[1:]):
        portfolio_df[stock] = scaled_df[stock] * weights[i] * initial_investment

    # Sum up all values and place the result in a new column titled "portfolio value [$]"
    # Note that we excluded the date column from this calculation
    portfolio_df['Portfolio Value [$]'] = portfolio_df[portfolio_df != 'Date'].sum(axis = 1, numeric_only = True)

    # Calculate the portfolio percentage daily return and replace NaNs with zeros
    portfolio_df['Portfolio Daily Return [%]'] = portfolio_df['Portfolio Value [$]'].pct_change(1) * 100
    portfolio_df.replace(np.nan, 0, inplace = True)

    return portfolio_df

# %%
# Let's define the simulation engine function
# The function receives:
    # (1) portfolio weights
    # (2) initial investment amount
# The function performs asset allocation and calculates portfolio statistical metrics including Sharpe ratio
# The function returns:
    # (1) Expected portfolio return
    # (2) Expected volatility
    # (3) Sharpe ratio
    # (4) Return on investment
    # (5) Final portfolio value in dollars


def simulation_engine(weights, initial_investment):
    # Perform asset allocation using the random weights (sent as arguments to the function)
    portfolio_df = asset_allocation(close_price_df, weights, initial_investment)

    # Calculate the return on the investment
    # Return on investment is calculated using the last final value of the portfolio compared to its initial value
    return_on_investment = ((portfolio_df['Portfolio Value [$]'][-1:] - portfolio_df['Portfolio Value [$]'][0])/
                             portfolio_df['Portfolio Value [$]'][0]) * 100

    # Daily change of every stock in the portfolio (Note that we dropped the date, portfolio daily worth and daily % returns)
    portfolio_daily_return_df = portfolio_df.drop(columns = ['Date', 'Portfolio Value [$]', 'Portfolio Daily Return [%]'])
    portfolio_daily_return_df = portfolio_daily_return_df.pct_change(1)

    # Portfolio Expected Return formula
    expected_portfolio_return = np.sum(weights * portfolio_daily_return_df.mean() ) * 252

    # Portfolio volatility (risk) formula
    # The risk of an asset is measured using the standard deviation which indicates the dispertion away from the mean
    # The risk of a portfolio is not a simple sum of the risks of the individual assets within the portfolio
    # Portfolio risk must consider correlations between assets within the portfolio which is indicated by the covariance
    # The covariance determines the relationship between the movements of two random variables
    # When two stocks move together, they have a positive covariance when they move inversely, the have a negative covariance

    covariance = portfolio_daily_return_df.cov() * 252
    expected_volatility = np.sqrt(np.dot(weights.T, np.dot(covariance, weights)))

    # Check out the chart for the 10-years U.S. treasury at https://ycharts.com/indicators/10_year_treasury_rate
    rf = 0.0425 # Try to set the risk free rate of return to 1% (assumption)

    # Calculate Sharpe ratio
    sharpe_ratio = (expected_portfolio_return - rf)/expected_volatility
    return expected_portfolio_return, expected_volatility, sharpe_ratio, portfolio_df['Portfolio Value [$]'][-1:].values[0], return_on_investment.values[0]

# %%
# Let's read multiple stocks data contained in "stock_prices.csv" attached in the course package
# The Appendix includes details on how to obtain this data using yfinance and Pandas Datareader
# Note that yfinance and Pandas Datareader might experience outage in some geographical regions

# We will focus our analysis on U.S. stocks, similar analysis could be performed on Asian, European or African stocks
# AMZN: Amazon Inc. - Multinational tech company focusing on e-commerce, cloud computing, and artificial intelligence
# JPM: JPMorgan Chase and Co. - Multinational investment bank and financial services holding company
# META: Meta Platforms, formerly named Facebook Inc. - META owns Facebook, Instagram, and WhatsApp
# PG: Procter and Gamble (P&G) - Multinational consumer goods corporation
# GOOG: Google (Alphabet Inc.) - Multinational company that focuses on search engine tech, e-commerce, Cloud and AI
# CAT: Caterpillar - World's largest construction-equipment manufacturer
# PFE: Pfizer Inc. - Multinational pharmaceutical and biotechnology corporation
# EXC: Exelon - An American Fortune 100 energy company
# DE: Deere & Company (John Deere) - Manufactures agricultural machinery and heavy equipment
# JNJ: Johnson & Johnson - A multinational corporation that develops medical devices and pharmaceuticals

close_price_df = pd.read_csv('stock_prices.csv')
close_price_df
# Out:
#             Date       AMZN         CAT          DE        EXC      GOOGL  \
# 0       1/2/2014  19.898500   69.512543   75.620926  14.121004  27.855856
# 1       1/3/2014  19.822001   69.473892   75.956062  13.835152  27.652653
# 2       1/6/2014  19.681499   68.561180   75.327690  13.923512  27.960960
# 3       1/7/2014  19.901501   68.785461   75.662811  13.996271  28.500000
# 4       1/8/2014  20.096001   68.947906   74.850121  13.965082  28.559309
# ...          ...        ...         ...         ...        ...        ...
# 2252  12/12/2022  90.550003  233.059998  437.049988  42.500000  93.309998
# 2253  12/13/2022  92.489998  235.490005  437.190002  42.540001  95.629997
# 2254  12/14/2022  91.580002  234.479996  438.440002  42.820000  95.070000
# 2255  12/15/2022  88.449997  230.660004  429.790008  42.380001  90.860001
# 2256  12/16/2022  87.860001  232.720001  431.089996  41.930000  90.260002
#
#              JNJ         JPM        META        PFE          PG
# 0      71.443314   45.640057   54.709999  20.879053   61.941517
# 1      72.086861   45.992889   54.560001  20.920183   61.872295
# 2      72.463608   46.259468   57.200001  20.940746   62.018425
# 3      74.001869   45.726311   57.919998  21.070980   62.618301
# 4      73.899841   46.157543   58.230000  21.214928   61.710812
# ...          ...         ...         ...        ...         ...
# 2252  177.839996  134.210007  114.709999  52.160000  152.470001
# 2253  179.210007  134.080002  120.150002  53.070000  152.240005
# 2254  179.759995  133.410004  121.589996  54.480000  152.839996
# 2255  177.490005  130.100006  116.150002  53.610001  151.110001
# 2256  175.669998  129.289993  119.430000  51.400002  150.440002
#
# [2257 rows x 11 columns]

# %%
# The objective of this code cell is to calculate the percentage daily return
# We will perform this calculation on all stocks except for the first column which is "Date"
daily_returns_df = close_price_df.iloc[:, 1:].pct_change() * 100
daily_returns_df.replace(np.nan, 0, inplace = True)
daily_returns_df
# Out:
#           AMZN       CAT        DE       EXC     GOOGL       JNJ       JPM  \
# 0     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1    -0.384451 -0.055602  0.443179 -2.024307 -0.729481  0.900780  0.773077
# 2    -0.708814 -1.313748 -0.827284  0.638662  1.114930  0.522629  0.579608
# 3     1.117807  0.327126  0.444884  0.522567  1.927829  2.122805 -1.152537
# 4     0.977313  0.236162 -1.074095 -0.222838  0.208102 -0.137872  0.943073
# ...        ...       ...       ...       ...       ...       ...       ...
# 2252  1.638800  2.538609  0.515165  2.607441  0.517070  1.194942  1.551152
# 2253  2.142457  1.042653  0.032036  0.094120  2.486336  0.770361 -0.096867
# 2254 -0.983886 -0.428897  0.285917  0.658201 -0.585588  0.306896 -0.499700
# 2255 -3.417782 -1.629133 -1.972903 -1.027554 -4.428315 -1.262789 -2.481072
# 2256 -0.667039  0.893088  0.302470 -1.061823 -0.660355 -1.025414 -0.622608
#
#           META       PFE        PG
# 0     0.000000  0.000000  0.000000
# 1    -0.274169  0.196992 -0.111753
# 2     4.838708  0.098293  0.236179
# 3     1.258737  0.621916  0.967255
# 4     0.535223  0.683156 -1.449240
# ...        ...       ...       ...
# 2252 -1.026749  0.850732  1.027036
# 2253  4.742396  1.744632 -0.150847
# 2254  1.198498  2.656868  0.394108
# 2255 -4.474048 -1.596914 -1.131900
# 2256  2.823933 -4.122363 -0.443384
#
# [2257 rows x 10 columns]

# %%
# Let's test out the "simulation_engine" function and print out statistical metrics
# Define the initial investment amount
weights = np.ones(10)/10
initial_investment = 1000000
portfolio_metrics = simulation_engine(weights, initial_investment)

print('Expected Portfolio Annual Return = {:.2f}%'.format(portfolio_metrics[0] * 100))
print('Portfolio Standard Deviation (Volatility) = {:.2f}%'.format(portfolio_metrics[1] * 100))
print('Sharpe Ratio = {:.2f}'.format(portfolio_metrics[2]))
print('Portfolio Final Value = ${:.2f}'.format(portfolio_metrics[3]))
print('Return on Investment = {:.2f}%'.format(portfolio_metrics[4]))
# Out:
# Expected Portfolio Annual Return = 16.30%
# Portfolio Standard Deviation (Volatility) = 18.02%
# Sharpe Ratio = 0.74
# Portfolio Final Value = $3203874.76
# Return on Investment = 220.39%

# %%
# Let's test out the "simulation_engine" function and print out statistical metrics
# Define the initial investment amount
initial_investment = 1000000
portfolio_metrics = simulation_engine(weights, initial_investment)

# %%
# Set the number of simulation runs
sim_runs = 10000
initial_investment = 1000000

# Placeholder to store all weights
n = 10
weights_runs = np.zeros((sim_runs, n))

# Placeholder to store all Sharpe ratios
sharpe_ratio_runs = np.zeros(sim_runs)

# Placeholder to store all expected returns
expected_portfolio_returns_runs = np.zeros(sim_runs)

# Placeholder to store all volatility values
volatility_runs = np.zeros(sim_runs)

# Placeholder to store all returns on investment
return_on_investment_runs = np.zeros(sim_runs)

# Placeholder to store all final portfolio values
final_value_runs = np.zeros(sim_runs)

for i in range(sim_runs):
    # Generate random weights
    weights = generate_portfolio_weights(n)
    # Store the weights
    weights_runs[i,:] = weights

    # Call "simulation_engine" function and store Sharpe ratio, return and volatility
    # Note that asset allocation is performed using the "asset_allocation" function
    expected_portfolio_returns_runs[i], volatility_runs[i], sharpe_ratio_runs[i], final_value_runs[i], return_on_investment_runs[i] = simulation_engine(weights, initial_investment)
    print("Simulation Run = {}".format(i))
    print("Weights = {}, Final Value = ${:.2f}, Sharpe Ratio = {:.2f}".format(weights_runs[i].round(3), final_value_runs[i], sharpe_ratio_runs[i]))
    print('\n')
# Out:
# Streaming output truncated to the last 5000 lines.
# Simulation Run = 8750
# Weights = [0.005 0.181 0.065 0.084 0.026 0.057 0.068 0.129 0.192 0.193], Final Value = $2886735.13, Sharpe Ratio = 0.62
#
#
# Simulation Run = 8751
# Weights = [0.183 0.086 0.105 0.139 0.063 0.017 0.159 0.033 0.122 0.094], Final Value = $3400365.44, Sharpe Ratio = 0.69
#
#
# Simulation Run = 8752
# Weights = [0.15  0.084 0.028 0.063 0.066 0.103 0.119 0.196 0.057 0.135], Final Value = $2986039.19, Sharpe Ratio = 0.61
#
#
# Simulation Run = 8753
# Weights = [0.046 0.143 0.126 0.109 0.059 0.094 0.081 0.157 0.085 0.1  ], Final Value = $3170364.93, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8754
# Weights = [0.142 0.092 0.116 0.074 0.007 0.087 0.059 0.146 0.139 0.137], Final Value = $3216896.06, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8755
# Weights = [0.14  0.043 0.028 0.146 0.23  0.089 0.037 0.15  0.093 0.044], Final Value = $3088209.19, Sharpe Ratio = 0.61
#
#
# Simulation Run = 8756
# Weights = [0.091 0.107 0.023 0.165 0.136 0.146 0.028 0.074 0.138 0.091], Final Value = $2986514.19, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8757
# Weights = [0.062 0.043 0.15  0.064 0.022 0.136 0.054 0.208 0.082 0.178], Final Value = $3112308.08, Sharpe Ratio = 0.64
#
#
# Simulation Run = 8758
# Weights = [0.041 0.183 0.048 0.031 0.17  0.024 0.105 0.105 0.177 0.115], Final Value = $3014757.76, Sharpe Ratio = 0.62
#
#
# Simulation Run = 8759
# Weights = [0.221 0.044 0.015 0.047 0.094 0.002 0.124 0.056 0.187 0.211], Final Value = $3101121.58, Sharpe Ratio = 0.64
#
#
# Simulation Run = 8760
# Weights = [0.112 0.139 0.165 0.048 0.034 0.142 0.006 0.164 0.174 0.015], Final Value = $3346297.71, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8761
# Weights = [0.146 0.013 0.062 0.17  0.204 0.172 0.036 0.142 0.033 0.022], Final Value = $3175981.71, Sharpe Ratio = 0.63
#
#
# Simulation Run = 8762
# Weights = [0.007 0.024 0.113 0.102 0.184 0.167 0.05  0.159 0.179 0.015], Final Value = $3030275.44, Sharpe Ratio = 0.62
#
#
# Simulation Run = 8763
# Weights = [0.046 0.132 0.192 0.036 0.182 0.022 0.131 0.101 0.1   0.06 ], Final Value = $3466905.58, Sharpe Ratio = 0.66
#
#
# Simulation Run = 8764
# Weights = [0.147 0.063 0.062 0.168 0.158 0.027 0.138 0.02  0.02  0.197], Final Value = $3252938.08, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8765
# Weights = [0.03  0.197 0.094 0.161 0.071 0.008 0.106 0.13  0.166 0.036], Final Value = $3139078.60, Sharpe Ratio = 0.64
#
#
# Simulation Run = 8766
# Weights = [0.04  0.064 0.031 0.24  0.113 0.092 0.059 0.051 0.288 0.023], Final Value = $2912968.65, Sharpe Ratio = 0.62
#
#
# Simulation Run = 8767
# Weights = [0.047 0.046 0.199 0.127 0.018 0.155 0.061 0.073 0.07  0.204], Final Value = $3312368.11, Sharpe Ratio = 0.70
#
#
# Simulation Run = 8768
# Weights = [0.126 0.058 0.067 0.121 0.111 0.129 0.143 0.107 0.041 0.096], Final Value = $3144730.00, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8769
# Weights = [0.014 0.098 0.069 0.072 0.008 0.169 0.07  0.15  0.141 0.209], Final Value = $2818412.79, Sharpe Ratio = 0.61
#
#
# Simulation Run = 8770
# Weights = [0.078 0.158 0.128 0.043 0.174 0.103 0.18  0.005 0.028 0.102], Final Value = $3387296.77, Sharpe Ratio = 0.66
#
#
# Simulation Run = 8771
# Weights = [0.132 0.123 0.065 0.097 0.12  0.112 0.11  0.006 0.087 0.149], Final Value = $3213821.37, Sharpe Ratio = 0.68
#
#
# Simulation Run = 8772
# Weights = [0.024 0.19  0.042 0.094 0.109 0.1   0.198 0.069 0.121 0.054], Final Value = $2999438.86, Sharpe Ratio = 0.61
#
#
# Simulation Run = 8773
# Weights = [0.176 0.198 0.085 0.021 0.056 0.066 0.123 0.007 0.224 0.043], Final Value = $3354097.01, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8774
# Weights = [0.171 0.122 0.159 0.111 0.133 0.104 0.069 0.007 0.087 0.036], Final Value = $3601365.26, Sharpe Ratio = 0.72
#
#
# Simulation Run = 8775
# Weights = [0.097 0.113 0.137 0.07  0.126 0.004 0.12  0.019 0.17  0.142], Final Value = $3364743.76, Sharpe Ratio = 0.69
#
#
# Simulation Run = 8776
# Weights = [0.056 0.148 0.015 0.124 0.147 0.086 0.12  0.166 0.091 0.047], Final Value = $2924968.49, Sharpe Ratio = 0.60
#
#
# Simulation Run = 8777
# Weights = [0.07  0.156 0.011 0.024 0.12  0.119 0.146 0.168 0.125 0.061], Final Value = $2884032.94, Sharpe Ratio = 0.59
#
#
# Simulation Run = 8778
# Weights = [0.18  0.144 0.076 0.086 0.036 0.131 0.17  0.023 0.083 0.071], Final Value = $3312958.18, Sharpe Ratio = 0.68
#
#
# Simulation Run = 8779
# Weights = [0.153 0.199 0.132 0.136 0.002 0.038 0.158 0.035 0.079 0.067], Final Value = $3482658.18, Sharpe Ratio = 0.69
#
#
# Simulation Run = 8780
# Weights = [0.069 0.125 0.168 0.068 0.155 0.023 0.178 0.068 0.003 0.144], Final Value = $3446745.21, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8781
# Weights = [0.04  0.209 0.057 0.067 0.16  0.093 0.067 0.08  0.106 0.121], Final Value = $3067997.50, Sharpe Ratio = 0.64
#
#
# Simulation Run = 8782
# Weights = [0.049 0.172 0.197 0.122 0.016 0.165 0.16  0.044 0.063 0.013], Final Value = $3468183.25, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8783
# Weights = [0.045 0.152 0.081 0.037 0.125 0.113 0.185 0.154 0.091 0.016], Final Value = $3089144.90, Sharpe Ratio = 0.61
#
#
# Simulation Run = 8784
# Weights = [0.116 0.134 0.168 0.052 0.068 0.084 0.044 0.051 0.158 0.125], Final Value = $3428132.99, Sharpe Ratio = 0.71
#
#
# Simulation Run = 8785
# Weights = [0.058 0.151 0.141 0.007 0.056 0.073 0.092 0.055 0.193 0.176], Final Value = $3224078.01, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8786
# Weights = [0.123 0.154 0.093 0.156 0.088 0.161 0.092 0.029 0.015 0.088], Final Value = $3310594.40, Sharpe Ratio = 0.69
#
#
# Simulation Run = 8787
# Weights = [0.066 0.142 0.156 0.123 0.08  0.135 0.052 0.104 0.011 0.131], Final Value = $3332415.71, Sharpe Ratio = 0.68
#
#
# Simulation Run = 8788
# Weights = [0.01  0.113 0.063 0.218 0.048 0.146 0.014 0.142 0.082 0.164], Final Value = $2893433.08, Sharpe Ratio = 0.63
#
#
# Simulation Run = 8789
# Weights = [0.065 0.133 0.094 0.08  0.107 0.123 0.026 0.138 0.094 0.139], Final Value = $3102489.93, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8790
# Weights = [0.192 0.035 0.005 0.093 0.171 0.18  0.151 0.018 0.044 0.112], Final Value = $3108632.16, Sharpe Ratio = 0.64
#
#
# Simulation Run = 8791
# Weights = [0.035 0.113 0.119 0.073 0.134 0.141 0.121 0.064 0.146 0.055], Final Value = $3182833.07, Sharpe Ratio = 0.66
#
#
# Simulation Run = 8792
# Weights = [0.046 0.118 0.01  0.291 0.022 0.216 0.111 0.042 0.002 0.144], Final Value = $2875573.55, Sharpe Ratio = 0.61
#
#
# Simulation Run = 8793
# Weights = [0.09  0.143 0.136 0.022 0.113 0.257 0.048 0.019 0.076 0.096], Final Value = $3312388.54, Sharpe Ratio = 0.69
#
#
# Simulation Run = 8794
# Weights = [0.097 0.104 0.244 0.026 0.218 0.04  0.03  0.002 0.17  0.069], Final Value = $3725464.01, Sharpe Ratio = 0.71
#
#
# Simulation Run = 8795
# Weights = [0.109 0.053 0.007 0.17  0.114 0.175 0.055 0.18  0.107 0.029], Final Value = $2886564.27, Sharpe Ratio = 0.60
#
#
# Simulation Run = 8796
# Weights = [0.112 0.109 0.018 0.098 0.09  0.025 0.149 0.15  0.103 0.145], Final Value = $2963753.60, Sharpe Ratio = 0.62
#
#
# Simulation Run = 8797
# Weights = [0.124 0.018 0.093 0.1   0.144 0.093 0.05  0.026 0.16  0.193], Final Value = $3188122.97, Sharpe Ratio = 0.68
#
#
# Simulation Run = 8798
# Weights = [0.038 0.112 0.051 0.157 0.117 0.141 0.131 0.07  0.052 0.13 ], Final Value = $2996393.98, Sharpe Ratio = 0.64
#
#
# Simulation Run = 8799
# Weights = [0.004 0.04  0.031 0.236 0.152 0.138 0.008 0.223 0.113 0.057], Final Value = $2779591.37, Sharpe Ratio = 0.57
#
#
# Simulation Run = 8800
# Weights = [0.05  0.102 0.102 0.03  0.097 0.116 0.078 0.099 0.182 0.143], Final Value = $3068690.20, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8801
# Weights = [0.149 0.061 0.19  0.108 0.063 0.165 0.049 0.035 0.074 0.106], Final Value = $3532344.62, Sharpe Ratio = 0.73
#
#
# Simulation Run = 8802
# Weights = [0.141 0.013 0.179 0.179 0.044 0.048 0.022 0.052 0.161 0.161], Final Value = $3442034.87, Sharpe Ratio = 0.72
#
#
# Simulation Run = 8803
# Weights = [0.166 0.173 0.079 0.005 0.077 0.085 0.118 0.002 0.105 0.189], Final Value = $3294317.30, Sharpe Ratio = 0.68
#
#
# Simulation Run = 8804
# Weights = [0.13  0.024 0.101 0.171 0.143 0.033 0.067 0.122 0.177 0.032], Final Value = $3253691.01, Sharpe Ratio = 0.66
#
#
# Simulation Run = 8805
# Weights = [0.04  0.054 0.105 0.094 0.099 0.147 0.113 0.044 0.182 0.123], Final Value = $3076562.92, Sharpe Ratio = 0.66
#
#
# Simulation Run = 8806
# Weights = [0.153 0.021 0.173 0.147 0.074 0.045 0.093 0.084 0.109 0.101], Final Value = $3479481.78, Sharpe Ratio = 0.71
#
#
# Simulation Run = 8807
# Weights = [0.207 0.087 0.096 0.167 0.051 0.056 0.147 0.148 0.038 0.003], Final Value = $3390760.49, Sharpe Ratio = 0.66
#
#
# Simulation Run = 8808
# Weights = [0.102 0.189 0.052 0.136 0.203 0.17  0.002 0.027 0.108 0.012], Final Value = $3215657.76, Sharpe Ratio = 0.66
#
#
# Simulation Run = 8809
# Weights = [0.014 0.103 0.062 0.074 0.159 0.175 0.115 0.1   0.156 0.042], Final Value = $2955036.88, Sharpe Ratio = 0.62
#
#
# Simulation Run = 8810
# Weights = [0.029 0.119 0.055 0.085 0.053 0.196 0.024 0.199 0.085 0.155], Final Value = $2832545.99, Sharpe Ratio = 0.61
#
#
# Simulation Run = 8811
# Weights = [0.051 0.151 0.182 0.175 0.027 0.166 0.186 0.038 0.019 0.005], Final Value = $3452301.23, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8812
# Weights = [0.118 0.186 0.019 0.008 0.093 0.009 0.017 0.198 0.146 0.205], Final Value = $2940872.71, Sharpe Ratio = 0.60
#
#
# Simulation Run = 8813
# Weights = [0.081 0.166 0.153 0.128 0.075 0.128 0.04  0.05  0.162 0.017], Final Value = $3384981.08, Sharpe Ratio = 0.69
#
#
# Simulation Run = 8814
# Weights = [0.065 0.185 0.02  0.069 0.08  0.052 0.171 0.099 0.109 0.15 ], Final Value = $2946230.15, Sharpe Ratio = 0.62
#
#
# Simulation Run = 8815
# Weights = [0.131 0.041 0.168 0.087 0.099 0.015 0.181 0.173 0.052 0.052], Final Value = $3437620.49, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8816
# Weights = [0.079 0.064 0.075 0.018 0.177 0.008 0.066 0.174 0.118 0.221], Final Value = $3031761.39, Sharpe Ratio = 0.61
#
#
# Simulation Run = 8817
# Weights = [0.078 0.172 0.065 0.097 0.137 0.107 0.14  0.023 0.045 0.136], Final Value = $3173983.44, Sharpe Ratio = 0.66
#
#
# Simulation Run = 8818
# Weights = [0.143 0.045 0.076 0.151 0.068 0.064 0.146 0.098 0.069 0.14 ], Final Value = $3178849.92, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8819
# Weights = [0.116 0.112 0.125 0.112 0.033 0.065 0.155 0.107 0.071 0.104], Final Value = $3298414.72, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8820
# Weights = [0.112 0.109 0.162 0.042 0.169 0.096 0.131 0.069 0.045 0.065], Final Value = $3480811.32, Sharpe Ratio = 0.68
#
#
# Simulation Run = 8821
# Weights = [0.075 0.07  0.105 0.01  0.051 0.144 0.167 0.045 0.162 0.173], Final Value = $3097248.22, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8822
# Weights = [0.122 0.156 0.118 0.14  0.111 0.029 0.025 0.134 0.14  0.025], Final Value = $3347710.69, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8823
# Weights = [0.139 0.145 0.014 0.124 0.139 0.067 0.117 0.01  0.159 0.086], Final Value = $3116374.62, Sharpe Ratio = 0.66
#
#
# Simulation Run = 8824
# Weights = [0.061 0.046 0.052 0.05  0.092 0.04  0.191 0.126 0.181 0.161], Final Value = $2916456.38, Sharpe Ratio = 0.61
#
#
# Simulation Run = 8825
# Weights = [0.151 0.142 0.112 0.107 0.017 0.18  0.1   0.017 0.058 0.114], Final Value = $3341317.15, Sharpe Ratio = 0.70
#
#
# Simulation Run = 8826
# Weights = [0.006 0.101 0.058 0.169 0.118 0.097 0.077 0.072 0.062 0.24 ], Final Value = $2928168.16, Sharpe Ratio = 0.63
#
#
# Simulation Run = 8827
# Weights = [0.092 0.033 0.07  0.032 0.135 0.162 0.121 0.024 0.157 0.174], Final Value = $3049223.15, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8828
# Weights = [0.125 0.147 0.094 0.096 0.185 0.068 0.066 0.056 0.149 0.015], Final Value = $3341122.69, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8829
# Weights = [0.076 0.055 0.157 0.101 0.071 0.083 0.109 0.124 0.08  0.142], Final Value = $3277563.01, Sharpe Ratio = 0.68
#
#
# Simulation Run = 8830
# Weights = [0.112 0.07  0.13  0.054 0.04  0.037 0.119 0.101 0.178 0.159], Final Value = $3232201.68, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8831
# Weights = [0.015 0.101 0.049 0.181 0.018 0.163 0.028 0.03  0.219 0.195], Final Value = $2840692.79, Sharpe Ratio = 0.62
#
#
# Simulation Run = 8832
# Weights = [0.018 0.114 0.032 0.129 0.129 0.067 0.068 0.141 0.172 0.13 ], Final Value = $2849329.73, Sharpe Ratio = 0.61
#
#
# Simulation Run = 8833
# Weights = [0.082 0.112 0.087 0.058 0.125 0.113 0.111 0.111 0.097 0.104], Final Value = $3137229.31, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8834
# Weights = [0.019 0.063 0.155 0.049 0.142 0.178 0.011 0.075 0.131 0.177], Final Value = $3169713.39, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8835
# Weights = [0.062 0.133 0.143 0.099 0.016 0.147 0.01  0.156 0.093 0.14 ], Final Value = $3182293.26, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8836
# Weights = [0.139 0.098 0.306 0.107 0.043 0.007 0.122 0.057 0.089 0.033], Final Value = $3926962.79, Sharpe Ratio = 0.72
#
#
# Simulation Run = 8837
# Weights = [0.058 0.017 0.085 0.026 0.217 0.03  0.197 0.044 0.154 0.173], Final Value = $3103050.32, Sharpe Ratio = 0.63
#
#
# Simulation Run = 8838
# Weights = [0.143 0.016 0.027 0.119 0.12  0.149 0.156 0.076 0.067 0.126], Final Value = $3030432.70, Sharpe Ratio = 0.64
#
#
# Simulation Run = 8839
# Weights = [0.019 0.101 0.118 0.175 0.096 0.154 0.062 0.052 0.073 0.15 ], Final Value = $3135393.61, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8840
# Weights = [0.059 0.089 0.054 0.149 0.112 0.142 0.157 0.017 0.13  0.092], Final Value = $3042066.59, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8841
# Weights = [0.163 0.18  0.053 0.147 0.084 0.035 0.035 0.167 0.089 0.045], Final Value = $3218874.81, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8842
# Weights = [0.084 0.016 0.083 0.13  0.086 0.123 0.122 0.111 0.118 0.127], Final Value = $3051738.90, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8843
# Weights = [0.055 0.122 0.137 0.113 0.126 0.165 0.034 0.035 0.107 0.106], Final Value = $3274600.23, Sharpe Ratio = 0.69
#
#
# Simulation Run = 8844
# Weights = [0.111 0.03  0.046 0.133 0.107 0.138 0.118 0.058 0.119 0.139], Final Value = $3030328.13, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8845
# Weights = [0.09  0.166 0.163 0.015 0.115 0.069 0.089 0.075 0.163 0.054], Final Value = $3421084.12, Sharpe Ratio = 0.68
#
#
# Simulation Run = 8846
# Weights = [0.207 0.142 0.022 0.126 0.067 0.089 0.1   0.133 0.013 0.102], Final Value = $3174563.57, Sharpe Ratio = 0.64
#
#
# Simulation Run = 8847
# Weights = [0.141 0.037 0.156 0.076 0.113 0.097 0.176 0.185 0.019 0.   ], Final Value = $3414181.59, Sharpe Ratio = 0.64
#
#
# Simulation Run = 8848
# Weights = [0.039 0.065 0.201 0.113 0.038 0.105 0.158 0.21  0.008 0.063], Final Value = $3331152.49, Sharpe Ratio = 0.64
#
#
# Simulation Run = 8849
# Weights = [0.159 0.037 0.157 0.051 0.147 0.134 0.093 0.183 0.015 0.023], Final Value = $3436985.66, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8850
# Weights = [0.132 0.143 0.141 0.113 0.093 0.031 0.035 0.102 0.137 0.072], Final Value = $3415321.73, Sharpe Ratio = 0.69
#
#
# Simulation Run = 8851
# Weights = [0.046 0.067 0.171 0.096 0.098 0.057 0.065 0.084 0.13  0.186], Final Value = $3284761.42, Sharpe Ratio = 0.69
#
#
# Simulation Run = 8852
# Weights = [0.21  0.049 0.202 0.163 0.002 0.009 0.213 0.057 0.014 0.08 ], Final Value = $3714415.79, Sharpe Ratio = 0.71
#
#
# Simulation Run = 8853
# Weights = [0.143 0.119 0.092 0.117 0.09  0.116 0.121 0.05  0.039 0.113], Final Value = $3301817.85, Sharpe Ratio = 0.68
#
#
# Simulation Run = 8854
# Weights = [0.005 0.162 0.122 0.038 0.08  0.055 0.099 0.17  0.063 0.205], Final Value = $3073765.81, Sharpe Ratio = 0.63
#
#
# Simulation Run = 8855
# Weights = [0.007 0.045 0.225 0.218 0.196 0.089 0.046 0.135 0.023 0.017], Final Value = $3485509.81, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8856
# Weights = [0.063 0.009 0.203 0.212 0.194 0.107 0.001 0.005 0.039 0.167], Final Value = $3502800.39, Sharpe Ratio = 0.71
#
#
# Simulation Run = 8857
# Weights = [0.068 0.079 0.059 0.127 0.173 0.084 0.027 0.175 0.066 0.142], Final Value = $3013336.38, Sharpe Ratio = 0.62
#
#
# Simulation Run = 8858
# Weights = [0.009 0.164 0.019 0.196 0.032 0.185 0.22  0.076 0.097 0.003], Final Value = $2871126.42, Sharpe Ratio = 0.59
#
#
# Simulation Run = 8859
# Weights = [0.126 0.093 0.118 0.106 0.092 0.107 0.137 0.08  0.023 0.119], Final Value = $3322189.02, Sharpe Ratio = 0.68
#
#
# Simulation Run = 8860
# Weights = [0.064 0.051 0.115 0.181 0.055 0.135 0.026 0.024 0.131 0.218], Final Value = $3134066.20, Sharpe Ratio = 0.68
#
#
# Simulation Run = 8861
# Weights = [0.119 0.109 0.155 0.075 0.076 0.044 0.172 0.041 0.183 0.027], Final Value = $3440885.72, Sharpe Ratio = 0.68
#
#
# Simulation Run = 8862
# Weights = [0.158 0.027 0.131 0.087 0.075 0.021 0.113 0.1   0.132 0.156], Final Value = $3330137.33, Sharpe Ratio = 0.68
#
#
# Simulation Run = 8863
# Weights = [0.04  0.005 0.199 0.202 0.036 0.08  0.184 0.083 0.08  0.091], Final Value = $3360551.03, Sharpe Ratio = 0.68
#
#
# Simulation Run = 8864
# Weights = [0.114 0.104 0.118 0.109 0.039 0.098 0.138 0.027 0.09  0.163], Final Value = $3283440.69, Sharpe Ratio = 0.69
#
#
# Simulation Run = 8865
# Weights = [0.156 0.128 0.052 0.126 0.159 0.097 0.034 0.141 0.063 0.046], Final Value = $3204821.41, Sharpe Ratio = 0.64
#
#
# Simulation Run = 8866
# Weights = [0.057 0.176 0.027 0.011 0.107 0.198 0.035 0.178 0.022 0.189], Final Value = $2861642.92, Sharpe Ratio = 0.60
#
#
# Simulation Run = 8867
# Weights = [0.069 0.131 0.14  0.216 0.02  0.027 0.223 0.126 0.031 0.017], Final Value = $3339009.82, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8868
# Weights = [0.167 0.02  0.096 0.105 0.179 0.13  0.094 0.016 0.04  0.152], Final Value = $3333760.37, Sharpe Ratio = 0.69
#
#
# Simulation Run = 8869
# Weights = [0.042 0.156 0.003 0.161 0.126 0.    0.188 0.041 0.185 0.099], Final Value = $2925904.34, Sharpe Ratio = 0.61
#
#
# Simulation Run = 8870
# Weights = [0.028 0.307 0.008 0.005 0.195 0.06  0.137 0.003 0.117 0.14 ], Final Value = $3014124.19, Sharpe Ratio = 0.60
#
#
# Simulation Run = 8871
# Weights = [0.135 0.065 0.156 0.039 0.164 0.035 0.081 0.184 0.108 0.033], Final Value = $3412714.49, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8872
# Weights = [0.168 0.018 0.113 0.167 0.109 0.073 0.123 0.026 0.036 0.168], Final Value = $3374808.74, Sharpe Ratio = 0.70
#
#
# Simulation Run = 8873
# Weights = [0.136 0.111 0.096 0.097 0.01  0.135 0.14  0.096 0.057 0.123], Final Value = $3212920.77, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8874
# Weights = [0.083 0.065 0.163 0.006 0.077 0.176 0.049 0.106 0.009 0.265], Final Value = $3251314.10, Sharpe Ratio = 0.68
#
#
# Simulation Run = 8875
# Weights = [0.017 0.008 0.193 0.087 0.178 0.152 0.062 0.093 0.043 0.167], Final Value = $3300615.01, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8876
# Weights = [0.109 0.053 0.088 0.127 0.17  0.076 0.021 0.13  0.058 0.167], Final Value = $3171825.98, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8877
# Weights = [0.041 0.157 0.026 0.14  0.135 0.054 0.057 0.147 0.132 0.11 ], Final Value = $2919604.11, Sharpe Ratio = 0.62
#
#
# Simulation Run = 8878
# Weights = [0.099 0.056 0.089 0.095 0.177 0.06  0.042 0.111 0.161 0.11 ], Final Value = $3161314.93, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8879
# Weights = [0.002 0.044 0.15  0.018 0.061 0.158 0.236 0.247 0.048 0.036], Final Value = $3064804.27, Sharpe Ratio = 0.59
#
#
# Simulation Run = 8880
# Weights = [0.005 0.097 0.131 0.014 0.147 0.047 0.165 0.011 0.185 0.198], Final Value = $3154910.04, Sharpe Ratio = 0.64
#
#
# Simulation Run = 8881
# Weights = [0.099 0.153 0.019 0.09  0.196 0.15  0.059 0.058 0.095 0.083], Final Value = $3050807.24, Sharpe Ratio = 0.64
#
#
# Simulation Run = 8882
# Weights = [0.108 0.053 0.076 0.134 0.206 0.032 0.164 0.013 0.085 0.13 ], Final Value = $3247243.32, Sharpe Ratio = 0.66
#
#
# Simulation Run = 8883
# Weights = [0.052 0.061 0.15  0.127 0.146 0.13  0.091 0.067 0.133 0.043], Final Value = $3293474.00, Sharpe Ratio = 0.68
#
#
# Simulation Run = 8884
# Weights = [0.128 0.163 0.133 0.049 0.135 0.123 0.029 0.071 0.077 0.093], Final Value = $3403792.55, Sharpe Ratio = 0.69
#
#
# Simulation Run = 8885
# Weights = [0.007 0.149 0.032 0.076 0.111 0.141 0.135 0.118 0.157 0.073], Final Value = $2851512.97, Sharpe Ratio = 0.60
#
#
# Simulation Run = 8886
# Weights = [0.088 0.2   0.16  0.052 0.106 0.08  0.038 0.061 0.029 0.187], Final Value = $3428089.62, Sharpe Ratio = 0.69
#
#
# Simulation Run = 8887
# Weights = [0.114 0.038 0.016 0.046 0.081 0.174 0.065 0.085 0.205 0.176], Final Value = $2851420.32, Sharpe Ratio = 0.62
#
#
# Simulation Run = 8888
# Weights = [0.15  0.157 0.039 0.087 0.094 0.14  0.032 0.218 0.049 0.033], Final Value = $3087383.21, Sharpe Ratio = 0.61
#
#
# Simulation Run = 8889
# Weights = [0.24  0.094 0.035 0.02  0.035 0.037 0.098 0.172 0.027 0.241], Final Value = $3146042.70, Sharpe Ratio = 0.63
#
#
# Simulation Run = 8890
# Weights = [0.029 0.008 0.043 0.008 0.22  0.178 0.143 0.221 0.063 0.087], Final Value = $2828184.67, Sharpe Ratio = 0.56
#
#
# Simulation Run = 8891
# Weights = [0.063 0.12  0.057 0.235 0.197 0.042 0.113 0.08  0.04  0.053], Final Value = $3164946.46, Sharpe Ratio = 0.64
#
#
# Simulation Run = 8892
# Weights = [0.136 0.022 0.042 0.11  0.103 0.083 0.111 0.101 0.171 0.12 ], Final Value = $3029675.20, Sharpe Ratio = 0.64
#
#
# Simulation Run = 8893
# Weights = [0.104 0.049 0.124 0.204 0.017 0.096 0.03  0.125 0.095 0.159], Final Value = $3195022.70, Sharpe Ratio = 0.68
#
#
# Simulation Run = 8894
# Weights = [0.033 0.142 0.062 0.121 0.154 0.025 0.157 0.084 0.145 0.079], Final Value = $3064931.71, Sharpe Ratio = 0.63
#
#
# Simulation Run = 8895
# Weights = [0.082 0.008 0.16  0.167 0.033 0.123 0.077 0.16  0.022 0.168], Final Value = $3236649.00, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8896
# Weights = [0.136 0.24  0.003 0.102 0.031 0.033 0.245 0.074 0.064 0.073], Final Value = $3090571.63, Sharpe Ratio = 0.62
#
#
# Simulation Run = 8897
# Weights = [0.149 0.107 0.077 0.127 0.145 0.018 0.081 0.151 0.065 0.081], Final Value = $3259219.15, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8898
# Weights = [0.05  0.063 0.184 0.227 0.009 0.023 0.112 0.019 0.158 0.155], Final Value = $3363800.44, Sharpe Ratio = 0.69
#
#
# Simulation Run = 8899
# Weights = [0.081 0.09  0.092 0.063 0.166 0.08  0.12  0.078 0.107 0.122], Final Value = $3177455.17, Sharpe Ratio = 0.66
#
#
# Simulation Run = 8900
# Weights = [0.053 0.022 0.066 0.166 0.036 0.068 0.222 0.107 0.085 0.176], Final Value = $2957574.90, Sharpe Ratio = 0.62
#
#
# Simulation Run = 8901
# Weights = [0.186 0.022 0.124 0.046 0.021 0.189 0.109 0.035 0.096 0.172], Final Value = $3310413.10, Sharpe Ratio = 0.70
#
#
# Simulation Run = 8902
# Weights = [0.129 0.026 0.171 0.031 0.    0.098 0.159 0.082 0.208 0.096], Final Value = $3339008.73, Sharpe Ratio = 0.68
#
#
# Simulation Run = 8903
# Weights = [0.124 0.055 0.014 0.033 0.18  0.072 0.16  0.104 0.142 0.116], Final Value = $2983141.29, Sharpe Ratio = 0.61
#
#
# Simulation Run = 8904
# Weights = [0.087 0.175 0.153 0.11  0.191 0.046 0.106 0.015 0.07  0.047], Final Value = $3521222.50, Sharpe Ratio = 0.68
#
#
# Simulation Run = 8905
# Weights = [0.163 0.032 0.13  0.064 0.163 0.005 0.099 0.092 0.158 0.093], Final Value = $3397734.57, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8906
# Weights = [0.077 0.122 0.079 0.147 0.076 0.126 0.047 0.093 0.131 0.103], Final Value = $3097341.86, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8907
# Weights = [0.221 0.204 0.007 0.006 0.084 0.119 0.051 0.078 0.032 0.198], Final Value = $3155036.96, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8908
# Weights = [0.132 0.102 0.092 0.113 0.109 0.13  0.049 0.096 0.136 0.04 ], Final Value = $3240053.49, Sharpe Ratio = 0.68
#
#
# Simulation Run = 8909
# Weights = [0.17  0.198 0.108 0.01  0.116 0.161 0.157 0.003 0.061 0.016], Final Value = $3470427.70, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8910
# Weights = [0.194 0.145 0.086 0.105 0.002 0.014 0.148 0.102 0.138 0.066], Final Value = $3327436.04, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8911
# Weights = [0.105 0.141 0.12  0.087 0.139 0.066 0.096 0.07  0.053 0.123], Final Value = $3346478.88, Sharpe Ratio = 0.68
#
#
# Simulation Run = 8912
# Weights = [0.029 0.004 0.025 0.079 0.128 0.166 0.147 0.146 0.105 0.171], Final Value = $2752371.81, Sharpe Ratio = 0.59
#
#
# Simulation Run = 8913
# Weights = [0.01  0.041 0.239 0.019 0.109 0.046 0.023 0.203 0.165 0.146], Final Value = $3332996.70, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8914
# Weights = [0.041 0.21  0.018 0.216 0.161 0.002 0.201 0.042 0.042 0.065], Final Value = $3083975.14, Sharpe Ratio = 0.61
#
#
# Simulation Run = 8915
# Weights = [0.077 0.009 0.153 0.152 0.082 0.154 0.07  0.147 0.022 0.136], Final Value = $3236605.66, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8916
# Weights = [0.153 0.162 0.152 0.084 0.128 0.095 0.103 0.04  0.005 0.078], Final Value = $3562234.82, Sharpe Ratio = 0.70
#
#
# Simulation Run = 8917
# Weights = [0.007 0.098 0.151 0.071 0.074 0.239 0.092 0.132 0.098 0.038], Final Value = $3139242.73, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8918
# Weights = [0.127 0.108 0.054 0.161 0.004 0.128 0.156 0.012 0.08  0.17 ], Final Value = $3114638.18, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8919
# Weights = [0.018 0.124 0.146 0.034 0.077 0.151 0.13  0.028 0.171 0.122], Final Value = $3192582.06, Sharpe Ratio = 0.66
#
#
# Simulation Run = 8920
# Weights = [0.015 0.173 0.156 0.065 0.161 0.119 0.004 0.08  0.15  0.077], Final Value = $3285588.66, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8921
# Weights = [0.141 0.018 0.085 0.146 0.111 0.12  0.142 0.075 0.096 0.065], Final Value = $3219238.97, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8922
# Weights = [0.046 0.154 0.024 0.044 0.144 0.2   0.075 0.053 0.052 0.208], Final Value = $2906016.29, Sharpe Ratio = 0.63
#
#
# Simulation Run = 8923
# Weights = [0.202 0.036 0.155 0.161 0.108 0.051 0.065 0.03  0.065 0.127], Final Value = $3567082.64, Sharpe Ratio = 0.72
#
#
# Simulation Run = 8924
# Weights = [0.124 0.123 0.062 0.147 0.064 0.136 0.076 0.083 0.065 0.121], Final Value = $3138479.24, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8925
# Weights = [0.234 0.19  0.09  0.149 0.093 0.103 0.067 0.031 0.03  0.013], Final Value = $3542433.36, Sharpe Ratio = 0.70
#
#
# Simulation Run = 8926
# Weights = [0.097 0.061 0.099 0.091 0.174 0.102 0.009 0.099 0.126 0.141], Final Value = $3178669.98, Sharpe Ratio = 0.66
#
#
# Simulation Run = 8927
# Weights = [0.034 0.17  0.108 0.2   0.024 0.095 0.137 0.064 0.122 0.046], Final Value = $3179693.95, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8928
# Weights = [0.013 0.205 0.022 0.165 0.054 0.015 0.165 0.098 0.184 0.08 ], Final Value = $2898327.33, Sharpe Ratio = 0.60
#
#
# Simulation Run = 8929
# Weights = [0.136 0.031 0.098 0.044 0.142 0.046 0.146 0.146 0.082 0.128], Final Value = $3214952.60, Sharpe Ratio = 0.64
#
#
# Simulation Run = 8930
# Weights = [0.129 0.143 0.104 0.097 0.108 0.103 0.002 0.13  0.048 0.136], Final Value = $3270950.90, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8931
# Weights = [0.178 0.047 0.019 0.045 0.144 0.088 0.134 0.081 0.233 0.03 ], Final Value = $3073215.68, Sharpe Ratio = 0.63
#
#
# Simulation Run = 8932
# Weights = [0.013 0.107 0.123 0.099 0.144 0.165 0.16  0.006 0.18  0.003], Final Value = $3200999.64, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8933
# Weights = [0.052 0.17  0.016 0.144 0.189 0.194 0.005 0.01  0.157 0.064], Final Value = $2979826.42, Sharpe Ratio = 0.64
#
#
# Simulation Run = 8934
# Weights = [0.15  0.122 0.019 0.135 0.003 0.151 0.117 0.089 0.06  0.156], Final Value = $3006754.47, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8935
# Weights = [0.129 0.05  0.083 0.099 0.099 0.145 0.104 0.094 0.146 0.051], Final Value = $3164344.98, Sharpe Ratio = 0.66
#
#
# Simulation Run = 8936
# Weights = [0.008 0.067 0.181 0.148 0.154 0.007 0.072 0.167 0.159 0.037], Final Value = $3297445.77, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8937
# Weights = [0.027 0.171 0.082 0.105 0.147 0.002 0.143 0.037 0.118 0.169], Final Value = $3136909.26, Sharpe Ratio = 0.64
#
#
# Simulation Run = 8938
# Weights = [0.049 0.102 0.117 0.081 0.154 0.159 0.075 0.131 0.003 0.13 ], Final Value = $3173591.40, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8939
# Weights = [0.183 0.01  0.176 0.166 0.013 0.056 0.044 0.053 0.166 0.132], Final Value = $3489259.26, Sharpe Ratio = 0.73
#
#
# Simulation Run = 8940
# Weights = [0.073 0.116 0.081 0.177 0.051 0.022 0.186 0.118 0.111 0.064], Final Value = $3132542.41, Sharpe Ratio = 0.64
#
#
# Simulation Run = 8941
# Weights = [0.098 0.073 0.124 0.032 0.128 0.137 0.132 0.112 0.078 0.086], Final Value = $3249029.28, Sharpe Ratio = 0.66
#
#
# Simulation Run = 8942
# Weights = [0.047 0.007 0.088 0.125 0.127 0.174 0.09  0.158 0.178 0.007], Final Value = $2995640.71, Sharpe Ratio = 0.62
#
#
# Simulation Run = 8943
# Weights = [0.152 0.093 0.094 0.071 0.034 0.098 0.142 0.155 0.138 0.023], Final Value = $3216172.67, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8944
# Weights = [0.024 0.026 0.08  0.104 0.074 0.136 0.048 0.263 0.043 0.203], Final Value = $2838458.02, Sharpe Ratio = 0.58
#
#
# Simulation Run = 8945
# Weights = [0.155 0.122 0.095 0.082 0.143 0.149 0.09  0.102 0.008 0.055], Final Value = $3335083.10, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8946
# Weights = [0.144 0.12  0.09  0.118 0.139 0.129 0.104 0.061 0.093 0.003], Final Value = $3328489.42, Sharpe Ratio = 0.68
#
#
# Simulation Run = 8947
# Weights = [0.182 0.059 0.012 0.185 0.011 0.129 0.017 0.139 0.09  0.177], Final Value = $2971643.25, Sharpe Ratio = 0.64
#
#
# Simulation Run = 8948
# Weights = [0.044 0.162 0.147 0.113 0.005 0.011 0.17  0.11  0.059 0.179], Final Value = $3255182.38, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8949
# Weights = [0.002 0.151 0.204 0.153 0.057 0.153 0.032 0.117 0.012 0.119], Final Value = $3357718.11, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8950
# Weights = [0.083 0.118 0.142 0.058 0.15  0.109 0.105 0.141 0.014 0.08 ], Final Value = $3330728.73, Sharpe Ratio = 0.66
#
#
# Simulation Run = 8951
# Weights = [0.125 0.052 0.014 0.163 0.013 0.115 0.174 0.026 0.192 0.126], Final Value = $2944507.60, Sharpe Ratio = 0.64
#
#
# Simulation Run = 8952
# Weights = [0.142 0.086 0.128 0.069 0.142 0.066 0.238 0.081 0.018 0.03 ], Final Value = $3439588.62, Sharpe Ratio = 0.66
#
#
# Simulation Run = 8953
# Weights = [0.1   0.159 0.063 0.135 0.062 0.005 0.16  0.07  0.177 0.068], Final Value = $3156245.95, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8954
# Weights = [0.073 0.111 0.122 0.011 0.197 0.023 0.133 0.04  0.164 0.126], Final Value = $3291381.92, Sharpe Ratio = 0.66
#
#
# Simulation Run = 8955
# Weights = [0.039 0.082 0.029 0.046 0.204 0.1   0.193 0.093 0.103 0.112], Final Value = $2927436.96, Sharpe Ratio = 0.60
#
#
# Simulation Run = 8956
# Weights = [0.042 0.058 0.153 0.158 0.162 0.092 0.151 0.044 0.011 0.13 ], Final Value = $3335331.83, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8957
# Weights = [0.098 0.052 0.026 0.114 0.193 0.184 0.031 0.081 0.047 0.174], Final Value = $2975092.40, Sharpe Ratio = 0.63
#
#
# Simulation Run = 8958
# Weights = [0.129 0.099 0.118 0.063 0.143 0.138 0.033 0.162 0.056 0.06 ], Final Value = $3290402.93, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8959
# Weights = [0.157 0.158 0.163 0.09  0.013 0.088 0.102 0.069 0.106 0.053], Final Value = $3509972.67, Sharpe Ratio = 0.70
#
#
# Simulation Run = 8960
# Weights = [0.103 0.027 0.009 0.112 0.052 0.119 0.165 0.214 0.019 0.182], Final Value = $2806726.92, Sharpe Ratio = 0.58
#
#
# Simulation Run = 8961
# Weights = [0.015 0.235 0.231 0.11  0.117 0.05  0.11  0.075 0.015 0.043], Final Value = $3612966.68, Sharpe Ratio = 0.66
#
#
# Simulation Run = 8962
# Weights = [0.109 0.052 0.125 0.165 0.151 0.035 0.064 0.019 0.151 0.129], Final Value = $3341444.86, Sharpe Ratio = 0.70
#
#
# Simulation Run = 8963
# Weights = [0.053 0.042 0.137 0.16  0.101 0.157 0.062 0.147 0.104 0.037], Final Value = $3187515.26, Sharpe Ratio = 0.66
#
#
# Simulation Run = 8964
# Weights = [0.109 0.124 0.117 0.116 0.04  0.015 0.149 0.04  0.152 0.139], Final Value = $3291619.66, Sharpe Ratio = 0.68
#
#
# Simulation Run = 8965
# Weights = [0.036 0.111 0.086 0.064 0.026 0.174 0.09  0.101 0.098 0.213], Final Value = $2960462.77, Sharpe Ratio = 0.64
#
#
# Simulation Run = 8966
# Weights = [0.097 0.184 0.002 0.135 0.168 0.111 0.035 0.125 0.139 0.004], Final Value = $2996162.26, Sharpe Ratio = 0.62
#
#
# Simulation Run = 8967
# Weights = [0.105 0.119 0.16  0.165 0.124 0.054 0.138 0.036 0.043 0.055], Final Value = $3511663.11, Sharpe Ratio = 0.69
#
#
# Simulation Run = 8968
# Weights = [0.077 0.038 0.095 0.182 0.065 0.168 0.079 0.002 0.183 0.112], Final Value = $3120229.03, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8969
# Weights = [0.039 0.014 0.105 0.244 0.03  0.036 0.233 0.119 0.17  0.01 ], Final Value = $3091275.02, Sharpe Ratio = 0.63
#
#
# Simulation Run = 8970
# Weights = [0.156 0.083 0.02  0.159 0.092 0.137 0.01  0.148 0.046 0.15 ], Final Value = $3014182.06, Sharpe Ratio = 0.63
#
#
# Simulation Run = 8971
# Weights = [0.015 0.127 0.142 0.027 0.066 0.151 0.165 0.076 0.15  0.081], Final Value = $3163824.55, Sharpe Ratio = 0.64
#
#
# Simulation Run = 8972
# Weights = [0.092 0.004 0.203 0.16  0.008 0.194 0.125 0.012 0.132 0.071], Final Value = $3429774.90, Sharpe Ratio = 0.71
#
#
# Simulation Run = 8973
# Weights = [0.001 0.137 0.09  0.077 0.209 0.08  0.059 0.142 0.193 0.012], Final Value = $3058757.48, Sharpe Ratio = 0.62
#
#
# Simulation Run = 8974
# Weights = [0.005 0.188 0.067 0.068 0.201 0.079 0.084 0.009 0.172 0.128], Final Value = $3070299.47, Sharpe Ratio = 0.63
#
#
# Simulation Run = 8975
# Weights = [0.081 0.069 0.153 0.153 0.161 0.15  0.123 0.068 0.032 0.01 ], Final Value = $3404443.81, Sharpe Ratio = 0.68
#
#
# Simulation Run = 8976
# Weights = [0.181 0.006 0.023 0.052 0.071 0.053 0.182 0.172 0.132 0.128], Final Value = $2992820.46, Sharpe Ratio = 0.61
#
#
# Simulation Run = 8977
# Weights = [0.152 0.067 0.091 0.078 0.062 0.042 0.1   0.143 0.151 0.112], Final Value = $3194432.65, Sharpe Ratio = 0.66
#
#
# Simulation Run = 8978
# Weights = [0.051 0.123 0.036 0.161 0.005 0.129 0.147 0.092 0.079 0.176], Final Value = $2895905.21, Sharpe Ratio = 0.63
#
#
# Simulation Run = 8979
# Weights = [0.085 0.205 0.021 0.223 0.034 0.062 0.06  0.203 0.021 0.086], Final Value = $2978001.77, Sharpe Ratio = 0.61
#
#
# Simulation Run = 8980
# Weights = [0.129 0.036 0.146 0.113 0.014 0.096 0.038 0.15  0.134 0.144], Final Value = $3255146.13, Sharpe Ratio = 0.68
#
#
# Simulation Run = 8981
# Weights = [0.066 0.161 0.062 0.155 0.008 0.025 0.144 0.117 0.159 0.103], Final Value = $3036904.33, Sharpe Ratio = 0.64
#
#
# Simulation Run = 8982
# Weights = [0.15  0.151 0.166 0.064 0.017 0.015 0.248 0.079 0.038 0.073], Final Value = $3537268.07, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8983
# Weights = [0.158 0.094 0.057 0.09  0.09  0.18  0.192 0.039 0.019 0.082], Final Value = $3210295.93, Sharpe Ratio = 0.66
#
#
# Simulation Run = 8984
# Weights = [0.107 0.033 0.15  0.015 0.132 0.045 0.168 0.159 0.17  0.021], Final Value = $3311267.51, Sharpe Ratio = 0.64
#
#
# Simulation Run = 8985
# Weights = [0.052 0.028 0.063 0.139 0.112 0.123 0.125 0.172 0.158 0.03 ], Final Value = $2945458.23, Sharpe Ratio = 0.61
#
#
# Simulation Run = 8986
# Weights = [0.066 0.051 0.018 0.139 0.113 0.15  0.141 0.125 0.068 0.129], Final Value = $2866629.53, Sharpe Ratio = 0.61
#
#
# Simulation Run = 8987
# Weights = [0.022 0.173 0.054 0.133 0.153 0.156 0.168 0.057 0.075 0.011], Final Value = $3063727.43, Sharpe Ratio = 0.63
#
#
# Simulation Run = 8988
# Weights = [0.131 0.056 0.012 0.13  0.117 0.055 0.162 0.07  0.106 0.162], Final Value = $2996909.44, Sharpe Ratio = 0.64
#
#
# Simulation Run = 8989
# Weights = [0.085 0.045 0.053 0.033 0.18  0.196 0.163 0.034 0.031 0.179], Final Value = $3041027.49, Sharpe Ratio = 0.64
#
#
# Simulation Run = 8990
# Weights = [0.145 0.04  0.212 0.157 0.069 0.03  0.105 0.182 0.012 0.049], Final Value = $3585102.29, Sharpe Ratio = 0.68
#
#
# Simulation Run = 8991
# Weights = [0.052 0.129 0.168 0.01  0.122 0.018 0.124 0.06  0.203 0.116], Final Value = $3344423.52, Sharpe Ratio = 0.67
#
#
# Simulation Run = 8992
# Weights = [0.04  0.148 0.017 0.136 0.05  0.131 0.089 0.138 0.137 0.115], Final Value = $2822563.82, Sharpe Ratio = 0.61
#
#
# Simulation Run = 8993
# Weights = [0.003 0.137 0.07  0.225 0.047 0.029 0.129 0.085 0.054 0.222], Final Value = $2982689.79, Sharpe Ratio = 0.62
#
#
# Simulation Run = 8994
# Weights = [0.126 0.053 0.121 0.071 0.119 0.09  0.176 0.139 0.034 0.073], Final Value = $3296646.81, Sharpe Ratio = 0.65
#
#
# Simulation Run = 8995
# Weights = [0.027 0.143 0.091 0.026 0.09  0.192 0.178 0.041 0.036 0.175], Final Value = $3069002.49, Sharpe Ratio = 0.63
#
#
# Simulation Run = 8996
# Weights = [0.074 0.028 0.009 0.134 0.187 0.032 0.113 0.171 0.097 0.154], Final Value = $2863524.75, Sharpe Ratio = 0.59
#
#
# Simulation Run = 8997
# Weights = [0.087 0.221 0.127 0.108 0.006 0.04  0.158 0.198 0.007 0.048], Final Value = $3301494.02, Sharpe Ratio = 0.63
#
#
# Simulation Run = 8998
# Weights = [0.056 0.095 0.172 0.213 0.049 0.125 0.    0.08  0.109 0.101], Final Value = $3333843.26, Sharpe Ratio = 0.70
#
#
# Simulation Run = 8999
# Weights = [0.079 0.054 0.14  0.156 0.175 0.013 0.157 0.055 0.103 0.068], Final Value = $3372076.88, Sharpe Ratio = 0.67
#
#
# Simulation Run = 9000
# Weights = [0.141 0.17  0.015 0.097 0.107 0.004 0.033 0.2   0.1   0.134], Final Value = $3019630.24, Sharpe Ratio = 0.61
#
#
# Simulation Run = 9001
# Weights = [0.065 0.046 0.09  0.013 0.168 0.177 0.064 0.01  0.179 0.189], Final Value = $3071421.96, Sharpe Ratio = 0.65
#
#
# Simulation Run = 9002
# Weights = [0.097 0.125 0.041 0.127 0.125 0.078 0.005 0.12  0.115 0.167], Final Value = $3019473.88, Sharpe Ratio = 0.65
#
#
# Simulation Run = 9003
# Weights = [0.212 0.091 0.004 0.191 0.08  0.183 0.069 0.009 0.042 0.119], Final Value = $3148755.29, Sharpe Ratio = 0.67
#
#
# Simulation Run = 9004
# Weights = [0.107 0.016 0.12  0.133 0.192 0.039 0.141 0.053 0.077 0.122], Final Value = $3323911.02, Sharpe Ratio = 0.67
#
#
# Simulation Run = 9005
# Weights = [0.173 0.019 0.033 0.126 0.093 0.084 0.087 0.149 0.078 0.158], Final Value = $3045612.32, Sharpe Ratio = 0.63
#
#
# Simulation Run = 9006
# Weights = [0.089 0.03  0.171 0.137 0.01  0.122 0.167 0.173 0.036 0.065], Final Value = $3304822.61, Sharpe Ratio = 0.66
#
#
# Simulation Run = 9007
# Weights = [0.116 0.149 0.113 0.053 0.025 0.024 0.1   0.135 0.152 0.134], Final Value = $3225589.36, Sharpe Ratio = 0.66
#
#
# Simulation Run = 9008
# Weights = [0.164 0.002 0.187 0.185 0.114 0.125 0.003 0.042 0.017 0.161], Final Value = $3556897.98, Sharpe Ratio = 0.73
#
#
# Simulation Run = 9009
# Weights = [0.166 0.101 0.002 0.125 0.067 0.17  0.141 0.069 0.099 0.059], Final Value = $3027478.52, Sharpe Ratio = 0.65
#
#
# Simulation Run = 9010
# Weights = [0.097 0.037 0.17  0.112 0.064 0.149 0.063 0.198 0.092 0.018], Final Value = $3308605.06, Sharpe Ratio = 0.66
#
#
# Simulation Run = 9011
# Weights = [0.13  0.113 0.109 0.151 0.075 0.139 0.068 0.039 0.146 0.032], Final Value = $3315620.93, Sharpe Ratio = 0.70
#
#
# Simulation Run = 9012
# Weights = [0.133 0.146 0.124 0.11  0.108 0.004 0.152 0.072 0.131 0.021], Final Value = $3427516.51, Sharpe Ratio = 0.67
#
#
# Simulation Run = 9013
# Weights = [0.04  0.114 0.145 0.052 0.275 0.143 0.007 0.03  0.111 0.083], Final Value = $3343120.49, Sharpe Ratio = 0.67
#
#
# Simulation Run = 9014
# Weights = [0.043 0.074 0.141 0.013 0.175 0.126 0.087 0.174 0.001 0.167], Final Value = $3187250.76, Sharpe Ratio = 0.63
#
#
# Simulation Run = 9015
# Weights = [0.106 0.105 0.082 0.043 0.143 0.123 0.111 0.066 0.115 0.105], Final Value = $3180322.70, Sharpe Ratio = 0.66
#
#
# Simulation Run = 9016
# Weights = [0.039 0.128 0.09  0.102 0.129 0.126 0.156 0.132 0.055 0.042], Final Value = $3114337.98, Sharpe Ratio = 0.63
#
#
# Simulation Run = 9017
# Weights = [0.187 0.114 0.127 0.179 0.058 0.001 0.113 0.093 0.027 0.102], Final Value = $3487793.43, Sharpe Ratio = 0.69
#
#
# Simulation Run = 9018
# Weights = [0.078 0.072 0.145 0.149 0.128 0.108 0.143 0.007 0.105 0.066], Final Value = $3370242.32, Sharpe Ratio = 0.69
#
#
# Simulation Run = 9019
# Weights = [0.171 0.03  0.175 0.192 0.016 0.02  0.063 0.127 0.01  0.197], Final Value = $3479187.00, Sharpe Ratio = 0.70
#
#
# Simulation Run = 9020
# Weights = [0.116 0.117 0.093 0.023 0.159 0.089 0.104 0.139 0.011 0.149], Final Value = $3221826.07, Sharpe Ratio = 0.64
#
#
# Simulation Run = 9021
# Weights = [0.011 0.042 0.173 0.06  0.102 0.007 0.152 0.135 0.164 0.153], Final Value = $3203574.01, Sharpe Ratio = 0.65
#
#
# Simulation Run = 9022
# Weights = [0.037 0.121 0.057 0.133 0.148 0.171 0.092 0.065 0.052 0.123], Final Value = $3019498.03, Sharpe Ratio = 0.64
#
#
# Simulation Run = 9023
# Weights = [0.07  0.249 0.162 0.016 0.015 0.057 0.023 0.126 0.039 0.244], Final Value = $3327185.91, Sharpe Ratio = 0.66
#
#
# Simulation Run = 9024
# Weights = [0.174 0.174 0.176 0.022 0.042 0.042 0.093 0.05  0.065 0.161], Final Value = $3586919.40, Sharpe Ratio = 0.70
#
#
# Simulation Run = 9025
# Weights = [0.061 0.031 0.025 0.157 0.113 0.214 0.108 0.2   0.079 0.012], Final Value = $2839753.52, Sharpe Ratio = 0.59
#
#
# Simulation Run = 9026
# Weights = [0.154 0.051 0.177 0.009 0.142 0.035 0.132 0.03  0.091 0.18 ], Final Value = $3531493.86, Sharpe Ratio = 0.70
#
#
# Simulation Run = 9027
# Weights = [0.019 0.006 0.087 0.092 0.019 0.226 0.009 0.188 0.126 0.228], Final Value = $2789185.19, Sharpe Ratio = 0.60
#
#
# Simulation Run = 9028
# Weights = [0.098 0.113 0.066 0.004 0.156 0.113 0.033 0.137 0.151 0.13 ], Final Value = $3059890.66, Sharpe Ratio = 0.63
#
#
# Simulation Run = 9029
# Weights = [0.076 0.077 0.149 0.161 0.019 0.164 0.178 0.133 0.032 0.01 ], Final Value = $3286054.91, Sharpe Ratio = 0.66
#
#
# Simulation Run = 9030
# Weights = [0.134 0.133 0.152 0.087 0.005 0.12  0.116 0.05  0.059 0.145], Final Value = $3403734.92, Sharpe Ratio = 0.70
#
#
# Simulation Run = 9031
# Weights = [0.145 0.01  0.098 0.116 0.145 0.09  0.063 0.131 0.047 0.156], Final Value = $3224615.83, Sharpe Ratio = 0.66
#
#
# Simulation Run = 9032
# Weights = [0.094 0.057 0.054 0.077 0.156 0.119 0.164 0.081 0.029 0.168], Final Value = $3064354.36, Sharpe Ratio = 0.64
#
#
# Simulation Run = 9033
# Weights = [0.185 0.045 0.144 0.096 0.145 0.022 0.068 0.051 0.179 0.065], Final Value = $3501904.40, Sharpe Ratio = 0.70
#
#
# Simulation Run = 9034
# Weights = [0.14  0.133 0.086 0.127 0.134 0.12  0.023 0.061 0.034 0.142], Final Value = $3287151.52, Sharpe Ratio = 0.69
#
#
# Simulation Run = 9035
# Weights = [0.008 0.049 0.144 0.127 0.213 0.151 0.144 0.131 0.025 0.008], Final Value = $3233766.84, Sharpe Ratio = 0.64
#
#
# Simulation Run = 9036
# Weights = [0.176 0.145 0.024 0.027 0.106 0.129 0.094 0.156 0.095 0.047], Final Value = $3098649.72, Sharpe Ratio = 0.62
#
#
# Simulation Run = 9037
# Weights = [0.138 0.125 0.054 0.001 0.161 0.076 0.095 0.166 0.013 0.17 ], Final Value = $3127758.21, Sharpe Ratio = 0.62
#
#
# Simulation Run = 9038
# Weights = [0.2   0.089 0.048 0.173 0.06  0.089 0.126 0.013 0.06  0.142], Final Value = $3258537.19, Sharpe Ratio = 0.69
#
#
# Simulation Run = 9039
# Weights = [0.128 0.073 0.134 0.004 0.125 0.098 0.154 0.073 0.192 0.02 ], Final Value = $3346469.35, Sharpe Ratio = 0.67
#
#
# Simulation Run = 9040
# Weights = [0.058 0.128 0.14  0.074 0.067 0.131 0.023 0.219 0.012 0.147], Final Value = $3175379.65, Sharpe Ratio = 0.64
#
#
# Simulation Run = 9041
# Weights = [0.037 0.006 0.103 0.099 0.024 0.116 0.138 0.158 0.183 0.136], Final Value = $2942825.26, Sharpe Ratio = 0.63
#
#
# Simulation Run = 9042
# Weights = [0.037 0.    0.006 0.247 0.04  0.016 0.166 0.269 0.02  0.199], Final Value = $2689443.66, Sharpe Ratio = 0.55
#
#
# Simulation Run = 9043
# Weights = [0.101 0.067 0.065 0.104 0.132 0.126 0.11  0.117 0.108 0.07 ], Final Value = $3088463.53, Sharpe Ratio = 0.65
#
#
# Simulation Run = 9044
# Weights = [0.093 0.138 0.127 0.081 0.055 0.073 0.079 0.136 0.071 0.147], Final Value = $3249837.46, Sharpe Ratio = 0.67
#
#
# Simulation Run = 9045
# Weights = [0.099 0.078 0.015 0.135 0.082 0.046 0.164 0.091 0.091 0.199], Final Value = $2935173.29, Sharpe Ratio = 0.63
#
#
# Simulation Run = 9046
# Weights = [0.115 0.009 0.203 0.196 0.113 0.016 0.011 0.107 0.141 0.09 ], Final Value = $3511883.55, Sharpe Ratio = 0.71
#
#
# Simulation Run = 9047
# Weights = [0.136 0.044 0.024 0.02  0.125 0.164 0.212 0.056 0.016 0.202], Final Value = $3007266.26, Sharpe Ratio = 0.63
#
#
# Simulation Run = 9048
# Weights = [0.12  0.121 0.029 0.143 0.021 0.077 0.16  0.043 0.085 0.201], Final Value = $3026876.24, Sharpe Ratio = 0.65
#
#
# Simulation Run = 9049
# Weights = [0.035 0.099 0.075 0.21  0.    0.13  0.119 0.116 0.156 0.061], Final Value = $2976386.48, Sharpe Ratio = 0.63
#
#
# Simulation Run = 9050
# Weights = [0.137 0.108 0.006 0.076 0.018 0.124 0.196 0.122 0.199 0.013], Final Value = $2934622.51, Sharpe Ratio = 0.61
#
#
# Simulation Run = 9051
# Weights = [0.01  0.013 0.223 0.126 0.028 0.064 0.191 0.024 0.176 0.145], Final Value = $3359010.77, Sharpe Ratio = 0.67
#
#
# Simulation Run = 9052
# Weights = [0.136 0.156 0.12  0.075 0.112 0.115 0.085 0.027 0.105 0.07 ], Final Value = $3402405.08, Sharpe Ratio = 0.69
#
#
# Simulation Run = 9053
# Weights = [0.009 0.003 0.136 0.122 0.006 0.219 0.199 0.188 0.081 0.037], Final Value = $3007578.25, Sharpe Ratio = 0.61
#
#
# Simulation Run = 9054
# Weights = [0.192 0.035 0.055 0.07  0.178 0.124 0.04  0.069 0.193 0.045], Final Value = $3214076.50, Sharpe Ratio = 0.65
#
#
# Simulation Run = 9055
# Weights = [0.114 0.132 0.057 0.097 0.142 0.072 0.125 0.106 0.037 0.117], Final Value = $3159419.82, Sharpe Ratio = 0.65
#
#
# Simulation Run = 9056
# Weights = [0.068 0.138 0.025 0.165 0.189 0.012 0.019 0.194 0.023 0.168], Final Value = $2974859.19, Sharpe Ratio = 0.60
#
#
# Simulation Run = 9057
# Weights = [0.148 0.064 0.142 0.168 0.098 0.068 0.061 0.069 0.055 0.127], Final Value = $3426897.02, Sharpe Ratio = 0.71
#
#
# Simulation Run = 9058
# Weights = [0.021 0.137 0.004 0.207 0.165 0.22  0.149 0.024 0.06  0.012], Final Value = $2919896.51, Sharpe Ratio = 0.61
#
#
# Simulation Run = 9059
# Weights = [0.029 0.096 0.091 0.019 0.085 0.121 0.154 0.155 0.085 0.166], Final Value = $2979475.80, Sharpe Ratio = 0.62
#
#
# Simulation Run = 9060
# Weights = [0.15  0.151 0.154 0.058 0.113 0.124 0.008 0.08  0.116 0.045], Final Value = $3485366.31, Sharpe Ratio = 0.70
#
#
# Simulation Run = 9061
# Weights = [0.104 0.09  0.097 0.112 0.144 0.145 0.123 0.044 0.005 0.137], Final Value = $3256234.95, Sharpe Ratio = 0.67
#
#
# Simulation Run = 9062
# Weights = [0.105 0.138 0.038 0.085 0.018 0.155 0.136 0.131 0.178 0.016], Final Value = $2981773.10, Sharpe Ratio = 0.63
#
#
# Simulation Run = 9063
# Weights = [0.162 0.165 0.1   0.153 0.066 0.097 0.063 0.083 0.04  0.072], Final Value = $3373372.38, Sharpe Ratio = 0.69
#
#
# Simulation Run = 9064
# Weights = [0.111 0.062 0.171 0.116 0.108 0.065 0.172 0.03  0.042 0.122], Final Value = $3482802.68, Sharpe Ratio = 0.70
#
#
# Simulation Run = 9065
# Weights = [0.031 0.07  0.109 0.16  0.126 0.117 0.106 0.151 0.068 0.061], Final Value = $3111807.03, Sharpe Ratio = 0.64
#
#
# Simulation Run = 9066
# Weights = [0.096 0.094 0.094 0.115 0.079 0.033 0.152 0.126 0.203 0.008], Final Value = $3177977.44, Sharpe Ratio = 0.65
#
#
# Simulation Run = 9067
# Weights = [0.136 0.045 0.026 0.069 0.04  0.167 0.169 0.022 0.197 0.127], Final Value = $2970693.50, Sharpe Ratio = 0.64
#
#
# Simulation Run = 9068
# Weights = [0.123 0.059 0.064 0.114 0.159 0.059 0.161 0.142 0.01  0.11 ], Final Value = $3157711.62, Sharpe Ratio = 0.63
#
#
# Simulation Run = 9069
# Weights = [0.141 0.048 0.077 0.134 0.042 0.05  0.158 0.099 0.12  0.131], Final Value = $3155597.89, Sharpe Ratio = 0.66
#
#
# Simulation Run = 9070
# Weights = [0.06  0.053 0.107 0.083 0.14  0.05  0.14  0.081 0.165 0.121], Final Value = $3146436.62, Sharpe Ratio = 0.65
#
#
# Simulation Run = 9071
# Weights = [0.112 0.083 0.147 0.134 0.174 0.068 0.083 0.063 0.056 0.081], Final Value = $3443706.53, Sharpe Ratio = 0.69
#
#
# Simulation Run = 9072
# Weights = [0.081 0.017 0.048 0.119 0.047 0.215 0.111 0.165 0.006 0.192], Final Value = $2874688.71, Sharpe Ratio = 0.61
#
#
# Simulation Run = 9073
# Weights = [0.125 0.048 0.007 0.062 0.056 0.186 0.207 0.04  0.069 0.199], Final Value = $2905705.92, Sharpe Ratio = 0.63
#
#
# Simulation Run = 9074
# Weights = [0.042 0.081 0.144 0.09  0.046 0.143 0.152 0.142 0.089 0.072], Final Value = $3174998.32, Sharpe Ratio = 0.65
#
#
# Simulation Run = 9075
# Weights = [0.082 0.175 0.033 0.119 0.123 0.049 0.167 0.026 0.11  0.117], Final Value = $3090963.48, Sharpe Ratio = 0.64
#
#
# Simulation Run = 9076
# Weights = [0.065 0.04  0.148 0.136 0.158 0.044 0.147 0.159 0.071 0.032], Final Value = $3304431.07, Sharpe Ratio = 0.65
#
#
# Simulation Run = 9077
# Weights = [0.01  0.1   0.084 0.142 0.082 0.152 0.082 0.111 0.126 0.111], Final Value = $2972775.09, Sharpe Ratio = 0.64
#
#
# Simulation Run = 9078
# Weights = [0.102 0.16  0.034 0.063 0.165 0.171 0.062 0.036 0.103 0.104], Final Value = $3083019.32, Sharpe Ratio = 0.65
#
#
# Simulation Run = 9079
# Weights = [0.109 0.093 0.166 0.051 0.12  0.096 0.141 0.022 0.016 0.185], Final Value = $3455856.29, Sharpe Ratio = 0.70
#
#
# Simulation Run = 9080
# Weights = [0.015 0.141 0.008 0.012 0.136 0.145 0.154 0.164 0.16  0.064], Final Value = $2763794.68, Sharpe Ratio = 0.57
#
#
# Simulation Run = 9081
# Weights = [0.166 0.012 0.103 0.104 0.089 0.175 0.156 0.065 0.041 0.088], Final Value = $3291404.63, Sharpe Ratio = 0.68
#
#
# Simulation Run = 9082
# ...
#
#
# Simulation Run = 9889
# Weights = [0.077 0.148 0.008 0.044 0.147 0.117 0.122 0.159 0.133 0.046], Final Value = $2903451.34, Sharpe Ratio = 0.60
#
#
# Simulation Run = 9890
# Weights = [0.094 0.016 0.146 0.066 0.134 0.095 0.056 0.124 0.12  0.151], Final Value = $3250810.89, Sharpe Ratio = 0.67
#
#
# Simulation Run = 9891
# Weights = [0.141 0.105 0.105 0.098 0.065 0.144 0.003 0.053 0.147 0.14 ], Final Value = $3251522.38, Sharpe Ratio = 0.70
#
#
# Simulation Run = 9892
# Weights = [0.078 0.124 0.027 0.132 0.174 0.087 0.121 0.023 0.186 0.048], Final Value = $3049983.34, Sharpe Ratio = 0.64
#
#
# Simulation Run = 9893
# Weights = [0.129 0.151 0.046 0.137 0.158 0.087 0.044 0.147 0.054 0.046], Final Value = $3162661.38, Sharpe Ratio = 0.64
#
#
# Simulation Run = 9894
# Weights = [0.002 0.069 0.148 0.149 0.016 0.144 0.078 0.148 0.153 0.092], Final Value = $3079966.50, Sharpe Ratio = 0.65
#
#
# Simulation Run = 9895
# Weights = [0.074 0.04  0.135 0.16  0.185 0.039 0.129 0.009 0.161 0.069], Final Value = $3347300.90, Sharpe Ratio = 0.68
#
#
# Simulation Run = 9896
# Weights = [0.081 0.127 0.028 0.126 0.    0.287 0.06  0.082 0.073 0.137], Final Value = $2879503.85, Sharpe Ratio = 0.64
#
#
# Simulation Run = 9897
# Weights = [0.052 0.094 0.03  0.167 0.148 0.082 0.068 0.025 0.181 0.152], Final Value = $2957735.24, Sharpe Ratio = 0.64
#
#
# Simulation Run = 9898
# Weights = [0.135 0.176 0.087 0.029 0.082 0.152 0.041 0.125 0.021 0.151], Final Value = $3218623.89, Sharpe Ratio = 0.66
#
#
# Simulation Run = 9899
# Weights = [0.162 0.039 0.215 0.067 0.14  0.122 0.118 0.085 0.013 0.038], Final Value = $3672412.01, Sharpe Ratio = 0.70
#
#
# Simulation Run = 9900
# Weights = [0.164 0.064 0.037 0.123 0.024 0.108 0.122 0.062 0.189 0.108], Final Value = $3062383.92, Sharpe Ratio = 0.66
#
#
# Simulation Run = 9901
# Weights = [0.127 0.122 0.209 0.076 0.052 0.116 0.117 0.104 0.023 0.053], Final Value = $3587237.92, Sharpe Ratio = 0.70
#
#
# Simulation Run = 9902
# Weights = [0.113 0.126 0.087 0.107 0.122 0.137 0.076 0.109 0.119 0.003], Final Value = $3223774.47, Sharpe Ratio = 0.66
#
#
# Simulation Run = 9903
# Weights = [0.137 0.029 0.027 0.134 0.055 0.183 0.075 0.077 0.101 0.182], Final Value = $2954086.14, Sharpe Ratio = 0.65
#
#
# Simulation Run = 9904
# Weights = [0.256 0.12  0.044 0.001 0.164 0.011 0.052 0.192 0.023 0.138], Final Value = $3300831.02, Sharpe Ratio = 0.61
#
#
# Simulation Run = 9905
# Weights = [0.043 0.123 0.082 0.125 0.097 0.152 0.104 0.078 0.112 0.084], Final Value = $3072900.78, Sharpe Ratio = 0.65
#
#
# Simulation Run = 9906
# Weights = [0.134 0.064 0.064 0.131 0.243 0.038 0.033 0.114 0.165 0.016], Final Value = $3220991.01, Sharpe Ratio = 0.64
#
#
# Simulation Run = 9907
# Weights = [0.156 0.037 0.137 0.154 0.102 0.012 0.05  0.053 0.142 0.156], Final Value = $3401260.91, Sharpe Ratio = 0.71
#
#
# Simulation Run = 9908
# Weights = [0.117 0.112 0.157 0.096 0.04  0.159 0.004 0.107 0.054 0.154], Final Value = $3343033.55, Sharpe Ratio = 0.70
#
#
# Simulation Run = 9909
# Weights = [0.179 0.087 0.123 0.04  0.136 0.036 0.047 0.073 0.166 0.114], Final Value = $3406438.91, Sharpe Ratio = 0.69
#
#
# Simulation Run = 9910
# Weights = [0.027 0.033 0.034 0.109 0.203 0.073 0.078 0.243 0.185 0.016], Final Value = $2826756.91, Sharpe Ratio = 0.56
#
#
# Simulation Run = 9911
# Weights = [0.14  0.063 0.085 0.056 0.169 0.152 0.086 0.189 0.007 0.053], Final Value = $3202912.75, Sharpe Ratio = 0.62
#
#
# Simulation Run = 9912
# Weights = [0.033 0.159 0.036 0.066 0.167 0.136 0.101 0.081 0.069 0.151], Final Value = $2957749.55, Sharpe Ratio = 0.62
#
#
# Simulation Run = 9913
# Weights = [0.137 0.052 0.153 0.099 0.099 0.133 0.113 0.114 0.076 0.024], Final Value = $3408014.15, Sharpe Ratio = 0.68
#
#
# Simulation Run = 9914
# Weights = [0.067 0.034 0.081 0.184 0.172 0.184 0.111 0.053 0.053 0.061], Final Value = $3135373.50, Sharpe Ratio = 0.66
#
#
# Simulation Run = 9915
# Weights = [0.119 0.031 0.151 0.078 0.048 0.149 0.07  0.149 0.139 0.066], Final Value = $3268685.67, Sharpe Ratio = 0.67
#
#
# Simulation Run = 9916
# Weights = [0.117 0.137 0.09  0.042 0.153 0.089 0.112 0.078 0.154 0.028], Final Value = $3260745.07, Sharpe Ratio = 0.66
#
#
# Simulation Run = 9917
# Weights = [0.178 0.093 0.089 0.154 0.176 0.003 0.095 0.065 0.061 0.087], Final Value = $3409063.66, Sharpe Ratio = 0.68
#
#
# Simulation Run = 9918
# Weights = [0.084 0.128 0.006 0.078 0.056 0.057 0.146 0.193 0.121 0.13 ], Final Value = $2837916.53, Sharpe Ratio = 0.59
#
#
# Simulation Run = 9919
# Weights = [0.041 0.01  0.097 0.167 0.003 0.116 0.132 0.121 0.153 0.161], Final Value = $2961148.85, Sharpe Ratio = 0.64
#
#
# Simulation Run = 9920
# Weights = [0.161 0.036 0.053 0.16  0.142 0.034 0.059 0.132 0.163 0.06 ], Final Value = $3155265.19, Sharpe Ratio = 0.64
#
#
# Simulation Run = 9921
# Weights = [0.09  0.175 0.083 0.018 0.071 0.051 0.182 0.061 0.177 0.094], Final Value = $3170880.85, Sharpe Ratio = 0.64
#
#
# Simulation Run = 9922
# Weights = [0.064 0.071 0.146 0.097 0.128 0.058 0.149 0.094 0.06  0.134], Final Value = $3294379.65, Sharpe Ratio = 0.67
#
#
# Simulation Run = 9923
# Weights = [0.096 0.158 0.03  0.112 0.078 0.169 0.05  0.059 0.221 0.027], Final Value = $3003425.73, Sharpe Ratio = 0.65
#
#
# Simulation Run = 9924
# Weights = [0.026 0.1   0.144 0.033 0.078 0.142 0.137 0.122 0.116 0.101], Final Value = $3157790.95, Sharpe Ratio = 0.65
#
#
# Simulation Run = 9925
# Weights = [0.14  0.153 0.153 0.088 0.108 0.066 0.06  0.047 0.058 0.127], Final Value = $3500329.08, Sharpe Ratio = 0.70
#
#
# Simulation Run = 9926
# Weights = [0.061 0.053 0.054 0.032 0.15  0.008 0.177 0.033 0.218 0.214], Final Value = $2983706.59, Sharpe Ratio = 0.63
#
#
# Simulation Run = 9927
# Weights = [0.098 0.112 0.011 0.085 0.171 0.118 0.062 0.175 0.012 0.157], Final Value = $2931384.83, Sharpe Ratio = 0.60
#
#
# Simulation Run = 9928
# Weights = [0.148 0.003 0.098 0.072 0.146 0.181 0.068 0.148 0.036 0.099], Final Value = $3203451.10, Sharpe Ratio = 0.65
#
#
# Simulation Run = 9929
# Weights = [0.135 0.103 0.127 0.048 0.114 0.088 0.132 0.107 0.011 0.135], Final Value = $3355957.41, Sharpe Ratio = 0.67
#
#
# Simulation Run = 9930
# Weights = [0.116 0.031 0.093 0.111 0.137 0.063 0.162 0.053 0.031 0.204], Final Value = $3216970.82, Sharpe Ratio = 0.67
#
#
# Simulation Run = 9931
# Weights = [0.14  0.186 0.031 0.017 0.006 0.033 0.084 0.154 0.191 0.158], Final Value = $2996505.96, Sharpe Ratio = 0.63
#
#
# Simulation Run = 9932
# Weights = [0.012 0.124 0.044 0.045 0.09  0.144 0.167 0.114 0.109 0.151], Final Value = $2854913.52, Sharpe Ratio = 0.61
#
#
# Simulation Run = 9933
# Weights = [0.229 0.044 0.129 0.046 0.183 0.07  0.039 0.138 0.103 0.018], Final Value = $3506366.19, Sharpe Ratio = 0.66
#
#
# Simulation Run = 9934
# Weights = [0.01  0.196 0.202 0.129 0.052 0.066 0.158 0.    0.114 0.073], Final Value = $3470310.60, Sharpe Ratio = 0.66
#
#
# Simulation Run = 9935
# Weights = [0.044 0.139 0.082 0.026 0.159 0.159 0.167 0.145 0.032 0.046], Final Value = $3094783.21, Sharpe Ratio = 0.61
#
#
# Simulation Run = 9936
# Weights = [0.1   0.09  0.123 0.11  0.064 0.109 0.104 0.127 0.076 0.097], Final Value = $3241279.88, Sharpe Ratio = 0.67
#
#
# Simulation Run = 9937
# Weights = [0.134 0.127 0.037 0.025 0.103 0.078 0.039 0.158 0.127 0.172], Final Value = $3014732.23, Sharpe Ratio = 0.63
#
#
# Simulation Run = 9938
# Weights = [0.135 0.118 0.024 0.221 0.005 0.044 0.019 0.069 0.161 0.205], Final Value = $3004906.32, Sharpe Ratio = 0.66
#
#
# Simulation Run = 9939
# Weights = [0.181 0.085 0.097 0.06  0.001 0.014 0.213 0.178 0.076 0.094], Final Value = $3262543.69, Sharpe Ratio = 0.64
#
#
# Simulation Run = 9940
# Weights = [0.156 0.186 0.067 0.01  0.006 0.183 0.188 0.147 0.051 0.006], Final Value = $3186293.09, Sharpe Ratio = 0.63
#
#
# Simulation Run = 9941
# Weights = [0.133 0.042 0.077 0.11  0.027 0.163 0.095 0.    0.185 0.168], Final Value = $3113163.36, Sharpe Ratio = 0.68
#
#
# Simulation Run = 9942
# Weights = [0.05  0.14  0.147 0.119 0.087 0.15  0.111 0.104 0.031 0.062], Final Value = $3296865.18, Sharpe Ratio = 0.67
#
#
# Simulation Run = 9943
# Weights = [0.13  0.077 0.111 0.181 0.037 0.056 0.082 0.105 0.151 0.07 ], Final Value = $3264240.45, Sharpe Ratio = 0.68
#
#
# Simulation Run = 9944
# Weights = [0.103 0.022 0.1   0.239 0.225 0.12  0.044 0.108 0.034 0.006], Final Value = $3287480.06, Sharpe Ratio = 0.65
#
#
# Simulation Run = 9945
# Weights = [0.195 0.077 0.011 0.002 0.159 0.176 0.181 0.048 0.065 0.085], Final Value = $3122322.63, Sharpe Ratio = 0.63
#
#
# Simulation Run = 9946
# Weights = [0.176 0.15  0.167 0.002 0.061 0.106 0.105 0.128 0.084 0.021], Final Value = $3529464.49, Sharpe Ratio = 0.68
#
#
# Simulation Run = 9947
# Weights = [0.091 0.044 0.064 0.104 0.138 0.122 0.087 0.135 0.094 0.121], Final Value = $3035607.18, Sharpe Ratio = 0.64
#
#
# Simulation Run = 9948
# Weights = [0.199 0.213 0.161 0.086 0.05  0.04  0.027 0.043 0.032 0.15 ], Final Value = $3637137.63, Sharpe Ratio = 0.71
#
#
# Simulation Run = 9949
# Weights = [0.134 0.031 0.068 0.172 0.071 0.192 0.179 0.014 0.117 0.025], Final Value = $3172990.17, Sharpe Ratio = 0.67
#
#
# Simulation Run = 9950
# Weights = [0.015 0.182 0.094 0.094 0.019 0.099 0.164 0.139 0.145 0.049], Final Value = $3040040.50, Sharpe Ratio = 0.62
#
#
# Simulation Run = 9951
# Weights = [0.158 0.166 0.003 0.088 0.11  0.005 0.08  0.11  0.078 0.202], Final Value = $3050957.93, Sharpe Ratio = 0.64
#
#
# Simulation Run = 9952
# Weights = [0.067 0.036 0.061 0.011 0.06  0.202 0.157 0.21  0.075 0.121], Final Value = $2868402.73, Sharpe Ratio = 0.59
#
#
# Simulation Run = 9953
# Weights = [0.066 0.191 0.134 0.072 0.074 0.057 0.13  0.108 0.116 0.053], Final Value = $3302730.66, Sharpe Ratio = 0.66
#
#
# Simulation Run = 9954
# Weights = [0.132 0.14  0.013 0.111 0.083 0.113 0.012 0.202 0.064 0.131], Final Value = $2949218.45, Sharpe Ratio = 0.61
#
#
# Simulation Run = 9955
# Weights = [0.192 0.039 0.111 0.037 0.104 0.019 0.049 0.167 0.11  0.173], Final Value = $3295758.27, Sharpe Ratio = 0.65
#
#
# Simulation Run = 9956
# Weights = [0.014 0.113 0.003 0.188 0.093 0.084 0.11  0.17  0.118 0.106], Final Value = $2759364.82, Sharpe Ratio = 0.59
#
#
# Simulation Run = 9957
# Weights = [0.032 0.189 0.151 0.139 0.063 0.025 0.029 0.082 0.199 0.091], Final Value = $3284331.42, Sharpe Ratio = 0.67
#
#
# Simulation Run = 9958
# Weights = [0.148 0.118 0.155 0.094 0.106 0.029 0.141 0.053 0.106 0.05 ], Final Value = $3524658.97, Sharpe Ratio = 0.69
#
#
# Simulation Run = 9959
# Weights = [0.176 0.048 0.049 0.028 0.194 0.051 0.168 0.021 0.134 0.132], Final Value = $3222452.92, Sharpe Ratio = 0.65
#
#
# Simulation Run = 9960
# Weights = [0.029 0.178 0.13  0.072 0.087 0.003 0.126 0.087 0.1   0.187], Final Value = $3219074.69, Sharpe Ratio = 0.65
#
#
# Simulation Run = 9961
# Weights = [0.11  0.181 0.163 0.126 0.083 0.05  0.072 0.012 0.1   0.102], Final Value = $3512630.16, Sharpe Ratio = 0.70
#
#
# Simulation Run = 9962
# Weights = [0.038 0.102 0.107 0.069 0.21  0.062 0.102 0.188 0.075 0.048], Final Value = $3152991.70, Sharpe Ratio = 0.61
#
#
# Simulation Run = 9963
# Weights = [0.111 0.1   0.114 0.199 0.126 0.152 0.002 0.105 0.058 0.033], Final Value = $3307715.38, Sharpe Ratio = 0.68
#
#
# Simulation Run = 9964
# Weights = [0.021 0.016 0.336 0.043 0.114 0.018 0.06  0.077 0.128 0.186], Final Value = $3711983.26, Sharpe Ratio = 0.71
#
#
# Simulation Run = 9965
# Weights = [0.117 0.013 0.111 0.2   0.195 0.075 0.001 0.094 0.101 0.094], Final Value = $3282865.83, Sharpe Ratio = 0.67
#
#
# Simulation Run = 9966
# Weights = [0.062 0.166 0.101 0.036 0.106 0.045 0.085 0.162 0.11  0.127], Final Value = $3138977.43, Sharpe Ratio = 0.64
#
#
# Simulation Run = 9967
# Weights = [0.06  0.146 0.019 0.13  0.188 0.174 0.164 0.07  0.037 0.011], Final Value = $3023841.54, Sharpe Ratio = 0.62
#
#
# Simulation Run = 9968
# Weights = [0.018 0.016 0.109 0.155 0.184 0.056 0.206 0.044 0.075 0.136], Final Value = $3147838.46, Sharpe Ratio = 0.64
#
#
# Simulation Run = 9969
# Weights = [0.083 0.237 0.006 0.057 0.065 0.208 0.197 0.005 0.098 0.044], Final Value = $3001654.55, Sharpe Ratio = 0.61
#
#
# Simulation Run = 9970
# Weights = [0.15  0.045 0.022 0.185 0.139 0.038 0.062 0.163 0.082 0.113], Final Value = $3044047.60, Sharpe Ratio = 0.62
#
#
# Simulation Run = 9971
# Weights = [0.093 0.171 0.168 0.07  0.063 0.126 0.034 0.125 0.126 0.022], Final Value = $3402565.79, Sharpe Ratio = 0.68
#
#
# Simulation Run = 9972
# Weights = [0.097 0.125 0.127 0.095 0.167 0.11  0.038 0.036 0.138 0.068], Final Value = $3350345.49, Sharpe Ratio = 0.69
#
#
# Simulation Run = 9973
# Weights = [0.2   0.012 0.121 0.022 0.127 0.03  0.2   0.024 0.205 0.059], Final Value = $3430959.98, Sharpe Ratio = 0.68
#
#
# Simulation Run = 9974
# Weights = [0.126 0.1   0.051 0.008 0.074 0.15  0.054 0.109 0.121 0.208], Final Value = $3006919.09, Sharpe Ratio = 0.64
#
#
# Simulation Run = 9975
# Weights = [0.114 0.08  0.108 0.061 0.148 0.118 0.096 0.145 0.114 0.015], Final Value = $3245837.28, Sharpe Ratio = 0.65
#
#
# Simulation Run = 9976
# Weights = [0.007 0.035 0.144 0.17  0.006 0.083 0.112 0.224 0.207 0.013], Final Value = $3042390.75, Sharpe Ratio = 0.62
#
#
# Simulation Run = 9977
# Weights = [0.118 0.001 0.15  0.155 0.087 0.152 0.142 0.099 0.091 0.005], Final Value = $3349076.03, Sharpe Ratio = 0.68
#
#
# Simulation Run = 9978
# Weights = [0.036 0.17  0.022 0.047 0.107 0.144 0.174 0.197 0.06  0.043], Final Value = $2869663.73, Sharpe Ratio = 0.58
#
#
# Simulation Run = 9979
# Weights = [0.049 0.076 0.137 0.126 0.022 0.032 0.19  0.057 0.29  0.022], Final Value = $3201891.28, Sharpe Ratio = 0.65
#
#
# Simulation Run = 9980
# Weights = [0.113 0.143 0.142 0.146 0.011 0.144 0.043 0.077 0.069 0.112], Final Value = $3340823.49, Sharpe Ratio = 0.70
#
#
# Simulation Run = 9981
# Weights = [0.041 0.084 0.115 0.074 0.02  0.173 0.083 0.165 0.062 0.184], Final Value = $3019096.69, Sharpe Ratio = 0.64
#
#
# Simulation Run = 9982
# Weights = [0.155 0.012 0.003 0.108 0.188 0.045 0.106 0.187 0.02  0.176], Final Value = $2966284.38, Sharpe Ratio = 0.58
#
#
# Simulation Run = 9983
# Weights = [0.144 0.032 0.084 0.132 0.161 0.014 0.141 0.103 0.116 0.072], Final Value = $3256865.63, Sharpe Ratio = 0.65
#
#
# Simulation Run = 9984
# Weights = [0.    0.103 0.141 0.021 0.117 0.055 0.224 0.099 0.183 0.057], Final Value = $3164229.76, Sharpe Ratio = 0.62
#
#
# Simulation Run = 9985
# Weights = [0.    0.028 0.146 0.136 0.142 0.056 0.161 0.192 0.012 0.128], Final Value = $3139696.71, Sharpe Ratio = 0.62
#
#
# Simulation Run = 9986
# Weights = [0.038 0.115 0.087 0.19  0.004 0.026 0.191 0.142 0.202 0.006], Final Value = $3048542.15, Sharpe Ratio = 0.62
#
#
# Simulation Run = 9987
# Weights = [0.03  0.16  0.172 0.172 0.144 0.021 0.072 0.162 0.03  0.037], Final Value = $3400133.22, Sharpe Ratio = 0.65
#
#
# Simulation Run = 9988
# Weights = [0.165 0.027 0.126 0.092 0.034 0.164 0.063 0.156 0.103 0.071], Final Value = $3266627.48, Sharpe Ratio = 0.67
#
#
# Simulation Run = 9989
# Weights = [0.082 0.057 0.202 0.007 0.191 0.075 0.045 0.148 0.07  0.123], Final Value = $3448201.04, Sharpe Ratio = 0.67
#
#
# Simulation Run = 9990
# Weights = [0.088 0.133 0.096 0.15  0.15  0.094 0.083 0.023 0.08  0.102], Final Value = $3276316.21, Sharpe Ratio = 0.68
#
#
# Simulation Run = 9991
# Weights = [0.105 0.085 0.118 0.084 0.125 0.076 0.151 0.12  0.086 0.049], Final Value = $3285155.70, Sharpe Ratio = 0.66
#
#
# Simulation Run = 9992
# Weights = [0.017 0.155 0.091 0.045 0.118 0.178 0.141 0.066 0.007 0.183], Final Value = $3067405.50, Sharpe Ratio = 0.63
#
#
# Simulation Run = 9993
# Weights = [0.066 0.123 0.076 0.002 0.069 0.209 0.093 0.224 0.12  0.018], Final Value = $2972778.44, Sharpe Ratio = 0.60
#
#
# Simulation Run = 9994
# Weights = [0.072 0.081 0.05  0.048 0.124 0.168 0.112 0.079 0.112 0.156], Final Value = $2968810.32, Sharpe Ratio = 0.64
#
#
# Simulation Run = 9995
# Weights = [0.221 0.028 0.148 0.096 0.199 0.035 0.079 0.15  0.012 0.031], Final Value = $3588642.44, Sharpe Ratio = 0.66
#
#
# Simulation Run = 9996
# Weights = [0.116 0.13  0.16  0.049 0.128 0.098 0.015 0.135 0.163 0.006], Final Value = $3412924.38, Sharpe Ratio = 0.67
#
#
# Simulation Run = 9997
# Weights = [0.145 0.104 0.125 0.098 0.045 0.106 0.08  0.134 0.145 0.019], Final Value = $3319012.64, Sharpe Ratio = 0.68
#
#
# Simulation Run = 9998
# Weights = [0.01  0.174 0.022 0.102 0.05  0.094 0.162 0.064 0.109 0.213], Final Value = $2831201.76, Sharpe Ratio = 0.60
#
#
# Simulation Run = 9999
# Weights = [0.061 0.169 0.019 0.095 0.115 0.084 0.048 0.148 0.072 0.189], Final Value = $2900776.30, Sharpe Ratio = 0.62

# %%
# List all Sharpe ratios generated from the simulation
sharpe_ratio_runs
# Out:
# array([0.67693584, 0.74368861, 0.71047646, ..., 0.71036324, 0.7352952 ,
#        0.7127702 ])

# %%
# Return the index of the maximum Sharpe ratio (Best simulation run)
print(sharpe_ratio_runs.argmax())
# Out:
# 318

# %%
# Return the maximum Sharpe ratio value
print(sharpe_ratio_runs.max().round(4))
# Out:
# 0.8214

# %%
# Obtain the portfolio weights that correspond to the maximum Sharpe ratio (Golden set of weights!)
print(weights_runs[sharpe_ratio_runs.argmax(), :])
# Out:
# [0.19370369 0.02302675 0.25033911 0.23385147 0.03638116 0.08407225
#  0.01549497 0.02736974 0.03471493 0.10104592]

# %%
# Return Sharpe ratio, volatility corresponding to the best weights allocation (maximum Sharpe ratio)
optimal_portfolio_return, optimal_volatility, optimal_sharpe_ratio, highest_final_value, optimal_return_on_investment = simulation_engine(weights_runs[sharpe_ratio_runs.argmax(), :], initial_investment)

print('Best Portfolio Metrics Based on {} Monte Carlo Simulation Runs:'.format(sim_runs))
print('  - Portfolio Expected Annual Return = {:.02f}%'.format(optimal_portfolio_return * 100))
print('  - Portfolio Standard Deviation (Volatility) = {:.02f}%'.format(optimal_volatility * 100))
print('  - Sharpe Ratio = {:.02f}'.format(optimal_sharpe_ratio))
print('  - Final Value = ${:.02f}'.format(highest_final_value))
print('  - Return on Investment = {:.02f}%'.format(optimal_return_on_investment))
# Out:
# Best Portfolio Metrics Based on 10000 Monte Carlo Simulation Runs:
#   - Portfolio Expected Annual Return = 17.64%
#   - Portfolio Standard Deviation (Volatility) = 17.82%
#   - Sharpe Ratio = 0.75
#   - Final Value = $3748355.75
#   - Return on Investment = 274.84%

# %%
# Return Sharpe ratio, volatility corresponding to the GMV
gmv_portfolio_return, gmv_volatility, gmv_sharpe_ratio, gmv_final_value, gmv_return_on_investment = simulation_engine(weights_runs[volatility_runs.argmin(), :], initial_investment)

print('GMV Portfolio Metrics Based on {} Monte Carlo Simulation Runs:'.format(sim_runs))
print('  - Portfolio Expected Annual Return = {:.02f}%'.format(gmv_portfolio_return * 100))
print('  - Portfolio Standard Deviation (Volatility) = {:.02f}%'.format(gmv_volatility * 100))
print('  - Sharpe Ratio = {:.02f}'.format(gmv_sharpe_ratio))
print('  - Final Value = ${:.02f}'.format(gmv_final_value))
print('  - Return on Investment = {:.02f}%'.format(gmv_return_on_investment))
# Out:
# GMV Portfolio Metrics Based on 10000 Monte Carlo Simulation Runs:
#   - Portfolio Expected Annual Return = 13.86%
#   - Portfolio Standard Deviation (Volatility) = 15.90%
#   - Sharpe Ratio = 0.60
#   - Final Value = $2835879.13
#   - Return on Investment = 183.59%

# %%
# Create a DataFrame that contains volatility, return, and Sharpe ratio for all simualation runs
sim_out_df = pd.DataFrame({'Volatility': volatility_runs.tolist(), 'Portfolio_Return': expected_portfolio_returns_runs.tolist(), 'Sharpe_Ratio': sharpe_ratio_runs.tolist() })
sim_out_df
# Out:
#       Volatility  Portfolio_Return  Sharpe_Ratio
# 0       0.180116          0.169025      0.702460
# 1       0.183595          0.154671      0.610970
# 2       0.176215          0.152872      0.626350
# 3       0.192294          0.170841      0.667417
# 4       0.179131          0.155974      0.633466
# ...          ...               ...           ...
# 9995    0.213562          0.182463      0.655378
# 9996    0.192387          0.172158      0.673942
# 9997    0.187221          0.169085      0.676128
# 9998    0.173040          0.147115      0.604571
# 9999    0.180117          0.153770      0.617768
#
# [10000 rows x 3 columns]

# %%
# Let's highlight the point with the highest Sharpe ratio
import plotly.graph_objects as go

factor = 1.2

# Calculate the extended x-coordinate
extended_volatility = optimal_volatility * factor

# Calculate the slope of the line between (0, 0.03) and (optimal_volatility, optimal_portfolio_return)
slope = (optimal_portfolio_return - 0.03) / optimal_volatility

# Compute the extended y-coordinate using the line equation: y = slope * x + intercept
extended_return = slope * extended_volatility + 0.03

fig = px.scatter(sim_out_df,
                 x='Volatility',
                 y='Portfolio_Return',
                 color='Sharpe_Ratio',
                 size='Sharpe_Ratio',
                 size_max=8,  # Adjust this value as needed
                 hover_data=['Sharpe_Ratio'])
# GMV portfolio
fig.add_trace(go.Scatter(x = [gmv_volatility], y = [gmv_portfolio_return],
                         mode = 'markers',
                         name = 'GMV',
                         marker=dict(
                         size=10,
                         color='green',
                         symbol='diamond'  # change to desired marker type
)
))
fig.add_trace(go.Scatter(x=[optimal_volatility],
                         y=[optimal_portfolio_return],
                         mode='markers',
                         name='Optimal Risky Portfolio',
                         marker=dict(
                         size=15,
                         color='red',
                         symbol='circle'  # change to desired marker type
)
))
fig.add_trace(go.Scatter(x = [0], y = [0.03],
                         mode = 'markers',
                         name = 'Risk-free asset',
                         marker=dict(
                         size=10,
                         color='blue',
                         symbol='square'  # change to desired marker type
)
))

# Add the extended line trace
fig.add_trace(go.Scatter(
    x=[0, extended_volatility],
    y=[0.03, extended_return],
    mode='lines',
    name='Capital Market Line (CML)',
    line=dict(color='black', dash='dash')
))
fig.update_layout(coloraxis_colorbar=dict(y=0.7, dtick=5))
fig.update_layout({'plot_bgcolor': "white"})

fig.update_layout(
    coloraxis_colorbar=dict(
        y=0.7,          # vertical position
        x=0.95,         # horizontal position, adjust as needed (0 is left, 1 is right)
        xanchor='left', # aligns the left side of the colorbar to the x position
        yanchor='middle',
        dtick=5
    )
)

fig.update_layout(coloraxis_showscale=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="70ace90e-3aea-4934-874a-8cb3bd714d07" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("70ace90e-3aea-4934-874a-8cb3bd714d07")) {                    Plotly.newPlot(                        "70ace90e-3aea-4934-874a-8cb3bd714d07",                        [{"customdata":[[0.7024597147454351],[0.6109699690373052],[0.6263501233227553],[0.6674171168880628],[0.6334662115736633],[0.6363335343828626],[0.6715017017484569],[0.7303877130448173],[0.6801222739692374],[0.631595360429811],[0.6533733937840789],[0.6561679788829113],[0.6636399895996292],[0.6572232465242975],[0.6567711686780355],[0.6755558323757777],[0.7174080851449286],[0.6087998598493803],[0.6532737451101296],[0.6453058563821109],[0.6621055556127742],[0.657064378001293],[0.6836604736448058],[0.6396320139191625],[0.624249036761363],[0.6219717202483438],[0.7038818342220546],[0.6563331706349111],[0.6462482635130238],[0.6647209165959626],[0.6682230510323449],[0.6729992151155271],[0.6630817862486683],[0.6732990516139531],[0.6897532634234248],[0.635712975653371],[0.6765943697548846],[0.6185450100251387],[0.6705283519706758],[0.6418726394844396],[0.6385815575892134],[0.6366018403061434],[0.6791811919465703],[0.6775303107653514],[0.6633515530609138],[0.6800580995087504],[0.7236019896916354],[0.6389587702877215],[0.6274912068266322],[0.6965034625347005],[0.694963725153999],[0.6070569719262121],[0.6277234230709244],[0.6209261434834334],[0.6747589282978664],[0.6589257982593997],[0.6929913026430886],[0.6541418023748852],[0.6149386465689012],[0.6553722093825273],[0.6683423119764451],[0.6696302119044466],[0.6473704594446892],[0.6705968484467167],[0.6551648204714943],[0.6400043542397936],[0.6870572832809452],[0.665866923141944],[0.5926340034507418],[0.7161886293501828],[0.6764689144169654],[0.6401299635700388],[0.6366466504291478],[0.689410698092678],[0.6267989665418879],[0.678302748107196],[0.6401825214384911],[0.691304825918242],[0.6223096655218088],[0.6887781826114776],[0.6643583233924044],[0.5796006740777465],[0.6720819977980605],[0.6296546940299038],[0.7022386471158268],[0.6687501292530232],[0.6205136694138126],[0.6402171555140342],[0.6719581294622479],[0.612216491786153],[0.6383284415427893],[0.6760039577261646],[0.6579516249240259],[0.6591612176406176],[0.6096281080158996],[0.5972851509187768],[0.6724484612693147],[0.6262795771592796],[0.6186948032108429],[0.6294495033824287],[0.6407206459895819],[0.5887763523911135],[0.6863834485759173],[0.6767448896053208],[0.6791214970856561],[0.6764860635315995],[0.6503704863772204],[0.6744666022750165],[0.6517249765417561],[0.6623253155180194],[0.602874402802069],[0.6497524287423965],[0.6647202014579372],[0.5935047719747717],[0.6961269600171338],[0.6614952477629665],[0.6528922786870545],[0.6481786104218739],[0.6927265733766431],[0.6781613592609911],[0.6804003291412056],[0.6759577559103866],[0.612369849786176],[0.6194067765952822],[0.6422264047210191],[0.6608307136906894],[0.6731892913125114],[0.6579658659834515],[0.6477468622884841],[0.6645168233367525],[0.6973628715140677],[0.602085488605905],[0.6166905011276228],[0.6638512042348994],[0.6384703778093703],[0.6715936332921183],[0.6578257949726082],[0.5897808305476054],[0.6197312128591675],[0.6013064559387553],[0.6040588307792941],[0.6324442912995459],[0.7051629576041205],[0.652167142642428],[0.6613175722675323],[0.6949032403345672],[0.6268730489290103],[0.6323182156478983],[0.6682781615591454],[0.6515318205007459],[0.6628809528222236],[0.5867527576063758],[0.6058661414754114],[0.6993553966109711],[0.6738895436255685],[0.6936069488269733],[0.643463847966736],[0.6127810111245755],[0.6118181335514422],[0.6944473606259419],[0.6566493849644679],[0.6288292838713103],[0.6375655215842257],[0.6807017392 ...
